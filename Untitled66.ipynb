# %%
import nltk,spacy

# %%
spacy.cli.download("en_core_web_lg")
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
nlp=spacy.load("en_core_web_lg")

# %%
doc=nlp("Dr. stage love sto eat the vadapav of mumbai. and he is currently love's the chaat of delhi")

# %%
for words in doc.sents:
  print(words)
# Out:
# Dr. stage love sto eat the vadapav of mumbai.
# and he is currently love's the chaat of delhi

# %%
from  nltk.tokenize import sent_tokenize

# %%
sent_tokenize("Dr. stage love sto eat the vadapav of mumbai. and he is currently love's the chaat of delhi")
# Out:
# ['Dr. stage love sto eat the vadapav of mumbai.',
#  "and he is currently love's the chaat of delhi"]

# %%
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> l
#
# Packages:
#   [ ] abc................. Australian Broadcasting Commission 2006
#   [ ] alpino.............. Alpino Dutch Treebank
#   [ ] averaged_perceptron_tagger Averaged Perceptron Tagger
#   [ ] averaged_perceptron_tagger_ru Averaged Perceptron Tagger (Russian)
#   [ ] basque_grammars..... Grammars for Basque
#   [ ] bcp47............... BCP-47 Language Tags
#   [ ] biocreative_ppi..... BioCreAtIvE (Critical Assessment of Information
#                            Extraction Systems in Biology)
#   [ ] bllip_wsj_no_aux.... BLLIP Parser: WSJ Model
#   [ ] book_grammars....... Grammars from NLTK Book
#   [ ] brown............... Brown Corpus
#   [ ] brown_tei........... Brown Corpus (TEI XML Version)
# ...
