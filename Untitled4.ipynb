# %%
print("Deepak")
# Out:
# Deepak

# %%
deepak=[[1,2,3],[4,5,6],[7,8,9]]

# %%
deepak[1][2]
# Out:
# 6

# %%
deepak[2][1]
# Out:
# 8

# %%
deepak=[]
# Out:
#   File "<ipython-input-6-a366264a31b9>", line 1
#     deepak=[[[`,1,23,`]]]
#               ^
# SyntaxError: invalid syntax

# %%
cart=[["watch",5000],["pen",100],["brik",400]]

# %%
deep=0
for i in range(len(cart)):
  deep=deep+cart[i][1]
print(deep)
# Out:
# 5500

# %%
# Out:
# 5500
