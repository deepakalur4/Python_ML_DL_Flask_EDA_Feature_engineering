# %%
print("Deepak")
# Out:
# Deepak

# %%
arr=list(map(int,input().split("-")))
# Out:
# 4-5-6-7-8

# %%
arr
# Out:
# [4, 5, 6, 7, 8]

# %%
inp_1=input().split()
a=set(input().split())
b=set(input().split())

sum([(i in a)-(i in b) for i in inp_1])
# Out:
# 4 5 6 6
# 3 4 5 6 7
# 3 4 5 6 7
# 0

# %%
 a = {2, 4, 5, 9}
b = {2, 4, 11, 12}

# %%
print(*(a.difference(b).union(b.difference(a))),sep="\n")
# Out:
# 9
# 11
# 12
# 5

# %%
print(len(set(input()) for i in range(int(input()))))
# Out:
# 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-2f0e31fac84a> in <module>
# ----> 1 print(len(set(input()) for i in range(int(input()))))
#
# TypeError: object of type 'generator' has no len()
