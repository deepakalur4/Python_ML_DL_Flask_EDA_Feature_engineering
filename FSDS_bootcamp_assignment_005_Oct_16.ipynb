# %% [markdown]
# # ASSIGNMENTS
# ## Send it before 0000 hrs IST or 12 AM Friday
#
# ## NOTE: Evaluation will be done before next class.
#
# ## HOW TO SUBMIT: -
# Download this notebook, Solve it and upload in the google form given in the mail.

# %% [markdown]
# # List, Tuple and Sets

# %% [markdown]
# #### 1. On amazon website we have the following available items -
#
# ```python
# amazon_website = [("watch", 5000), ("phone", 10000), ("laptop", 50000), ("shirt", 1000)]
# ```
# Take the user input N no. of times and find out the total cost to be paid?
#
# OR
#
# You can ask the user quntity or the count of item?
#
# if the item is not present in the amazon website then print that item as out of stock and do add it total
#
#
# HINT: while, for loop.. indexing

# %%
amazon_website = [("watch", 5000), ("phone", 10000), ("laptop", 50000), ("shirt", 1000)]
# i=0
#  while True:
# item,price=input("Please enter the item if want to add to the list: ")
# total_cost=0
# for i in amazon_website:
#   print(i[0])
  # total_cost_=total_cost+i[1]
# print(total_cost)
# i=0
total_amount=0
while True:
  item=tuple(input("Please enter the item and the price you want to add to the list or q to finalise the list : ").split(" "))
  # total_amount=total_amount+(int(amazon_website[1]))
  if item[0] != "q":
    if item[0] not in amazon_website[0]:
       amazon_website.append(item)
       print(f"The new list is: {amazon_website}")
       
       

    else:
      print(f"The {item[0]} is already present in the list: {amazon_website}")

    
    
    # total_cost=0


  else:
    for i in range(len(amazon_website)):
      total_amount=total_amount+int(amazon_website[i][1])
    print(total_amount)
      # print(f"The final amount needs to be paid: ))
    break
  
    # print(f"The item has been added to the list, New list is: {amazon_website} ")  
    #     print("This item is already present in the list: ")
    # print("Please enter q to finalise the list: ")  
    



       
        
    #     total_cost=total_cost+int(lists[1])
    # print(f"The total cost needs tbe paid : {total_cost}")
    #   #   print("Please enter q to finalise the list: ")

  # else:
# Out:
# Please enter the item and the price you want to add to the list or q to finalise the list : pen 44
# The new list is: [('watch', 5000), ('phone', 10000), ('laptop', 50000), ('shirt', 1000), ('pen', '44')]
# Please enter the item and the price you want to add to the list or q to finalise the list : asda 77
# The new list is: [('watch', 5000), ('phone', 10000), ('laptop', 50000), ('shirt', 1000), ('pen', '44'), ('asda', '77')]
# Please enter the item and the price you want to add to the list or q to finalise the list : q
# 66121

# %%
int(99)
# Out:
# 99

# %% [markdown]
# #### 2. What will be the output of the following code snippet?
#
# ```
# arr = [1, 2, 3, 4, 5, 6]
# for i in range(1, 6):
#     arr[i - 1] = arr[i]
# for i in range(0, 6):
#     print(arr[i], end = " ")
# ```

# %% [markdown]
# #### 3. Write a Python program to find the repeated items of a tuple.

# %% [markdown]
# ### 4. Replace last value of tuples in a list with 500. Try using list comprehension
#
# Example -:
# ```
# Input -:
#
# [(10, 20, 40), (40, 50, 60), (70, 80, 90)]
#
# Output -:
# [(10, 20, 500), (40, 50, 500), (70, 80, 500)]
#
#
# ```
