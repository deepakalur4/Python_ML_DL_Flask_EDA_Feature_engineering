# %%
import seaborn as sns

# %%
data=sns.load_dataset("titanic")

# %%
data.shape
# Out:
# (891, 15)

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
data[data.duplicated()]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 47          1       3  female   NaN      0      0   7.7500        Q   Third
# 76          0       3    male   NaN      0      0   7.8958        S   Third
# 77          0       3    male   NaN      0      0   8.0500        S   Third
# 87          0       3    male   NaN      0      0   8.0500        S   Third
# 95          0       3    male   NaN      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 870         0       3    male  26.0      0      0   7.8958        S   Third
# 877         0       3    male  19.0      0      0   7.8958        S   Third
# 878         0       3    male   NaN      0      0   7.8958        S   Third
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data[["pclass"]]
# Out:
#      pclass
# 0         3
# 1         1
# 2         3
# 3         1
# 4         3
# ..      ...
# 886       2
# 887       1
# 888       3
# 889       1
# 890       3
#
# [891 rows x 1 columns]

# %%
data[["pclass"]].shape
# Out:
# (891, 1)

# %%
data["pclass"].dtype
# Out:
# dtype('int64')

# %%
data.who.str.isnumeric()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: who, Length: 891, dtype: bool

# %%
data[data.who.str.isnumeric()]
# Out:
# Empty DataFrame
# Columns: [survived, pclass, sex, age, sibsp, parch, fare, embarked, class, who, adult_male, deck, embark_town, alive, alone]
# Index: []

# %%
data[~data.who.str.isnumeric()]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data["pclass"]=data["pclass"].astype("str")

# %%
data["pclass"].dtype
# Out:
# dtype('O')

# %%
data["pclass"]=data["pclass"].astype("int")

# %%
data["fare"].unique()
# Out:
# array([  7.25  ,  71.2833,   7.925 ,  53.1   ,   8.05  ,   8.4583,
#         51.8625,  21.075 ,  11.1333,  30.0708,  16.7   ,  26.55  ,
#         31.275 ,   7.8542,  16.    ,  29.125 ,  13.    ,  18.    ,
#          7.225 ,  26.    ,   8.0292,  35.5   ,  31.3875, 263.    ,
#          7.8792,   7.8958,  27.7208, 146.5208,   7.75  ,  10.5   ,
#         82.1708,  52.    ,   7.2292,  11.2417,   9.475 ,  21.    ,
#         41.5792,  15.5   ,  21.6792,  17.8   ,  39.6875,   7.8   ,
#         76.7292,  61.9792,  27.75  ,  46.9   ,  80.    ,  83.475 ,
#         27.9   ,  15.2458,   8.1583,   8.6625,  73.5   ,  14.4542,
#         56.4958,   7.65  ,  29.    ,  12.475 ,   9.    ,   9.5   ,
#          7.7875,  47.1   ,  15.85  ,  34.375 ,  61.175 ,  20.575 ,
#         34.6542,  63.3583,  23.    ,  77.2875,   8.6542,   7.775 ,
#         24.15  ,   9.825 ,  14.4583, 247.5208,   7.1417,  22.3583,
#          6.975 ,   7.05  ,  14.5   ,  15.0458,  26.2833,   9.2167,
# ...

# %%
data["sex"].str.isnumeric()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: sex, Length: 891, dtype: bool

# %%
data["sex"].str.replace("le","Deepak")
# Out:
# 0        maDeepak
# 1      femaDeepak
# 2      femaDeepak
# 3      femaDeepak
# 4        maDeepak
#           ...
# 886      maDeepak
# 887    femaDeepak
# 888    femaDeepak
# 889      maDeepak
# 890      maDeepak
# Name: sex, Length: 891, dtype: object

# %%
import numpy as np

# %%
np.nan
# Out:
# nan

# %%
for i in data["fare"]:
  print(i)
# Out:
# 7.25
# 71.2833
# 7.925
# 53.1
# 8.05
# 8.4583
# 51.8625
# 21.075
# 11.1333
# 30.0708
# 16.7
# 26.55
# 8.05
# 31.275
# 7.8542
# 16.0
# 29.125
# 13.0
# 18.0
# 7.225
# 26.0
# 13.0
# 8.0292
# 35.5
# 21.075
# 31.3875
# 7.225
# 263.0
# 7.8792
# 7.8958
# 27.7208
# 146.5208
# 7.75
# 10.5
# 82.1708
# 52.0
# 7.2292
# 8.05
# 18.0
# 11.2417
# 9.475
# 21.0
# 7.8958
# 41.5792
# 7.8792
# 8.05
# 15.5
# 7.75
# 21.6792
# 17.8
# 39.6875
# 7.8
# 76.7292
# 26.0
# 61.9792
# 35.5
# 10.5
# 7.2292
# 27.75
# 46.9
# 7.2292
# 80.0
# 83.475
# 27.9
# 27.7208
# 15.2458
# 10.5
# 8.1583
# 7.925
# 8.6625
# 10.5
# 46.9
# 73.5
# 14.4542
# 56.4958
# 7.65
# 7.8958
# 8.05
# 29.0
# 12.475
# 9.0
# 9.5
# 7.7875
# 47.1
# 10.5
# 15.85
# 34.375
# 8.05
# 263.0
# 8.05
# 8.05
# 7.8542
# 61.175
# 20.575
# 7.25
# 8.05
# 34.6542
# 63.3583
# 23.0
# 26.0
# 7.8958
# 7.8958
# 77.2875
# 8.6542
# 7.925
# 7.8958
# 7.65
# 7.775
# 7.8958
# 24.15
# 52.0
# 14.4542
# 8.05
# 9.825
# 14.4583
# 7.925
# 7.75
# 21.0
# 247.5208
# 31.275
# 73.5
# 8.05
# ...

# %%
for i in data["fare"]:
  if i>50:
    print(i)
# Out:
# 71.2833
# 53.1
# 51.8625
# 263.0
# 146.5208
# 82.1708
# 52.0
# 76.7292
# 61.9792
# 80.0
# 83.475
# 73.5
# 56.4958
# 263.0
# 61.175
# 63.3583
# 77.2875
# 52.0
# 247.5208
# 73.5
# 77.2875
# 53.1
# 79.2
# 66.6
# 61.3792
# 69.55
# 55.0
# 56.4958
# 69.55
# 146.5208
# 69.55
# 113.275
# 76.2917
# 90.0
# 83.475
# 90.0
# 52.5542
# 79.2
# 86.5
# 512.3292
# 79.65
# 153.4625
# 135.6333
# 77.9583
# 78.85
# 91.0792
# 151.55
# 247.5208
# 151.55
# 110.8833
# 108.9
# 56.9292
# 83.1583
# 262.375
# 164.8667
# 134.5
# 69.55
# 135.6333
# 57.9792
# 153.4625
# 133.65
# 66.6
# 134.5
# 263.0
# 55.0
# 75.25
# 69.3
# 55.4417
# 135.6333
# 82.1708
# 211.5
# 227.525
# 52.0
# 73.5
# 120.0
# 113.275
# 90.0
# 55.9
# 120.0
# 263.0
# 81.8583
# 89.1042
# 51.8625
# 52.0
# 91.0792
# 90.0
# 78.2667
# 151.55
# 86.5
# 108.9
# 56.4958
# 59.4
# 93.5
# 57.9792
# 221.7792
# 106.425
# 71.0
# 106.425
# 110.8833
# 227.525
# 79.65
# 51.4792
# 55.9
# 110.8833
# 79.65
# 79.2
# 78.2667
# 56.9292
# 153.4625
# 65.0
# 52.5542
# 77.9583
# ...

# %%
import seaborn as sns

# %%
data=sns.load_dataset("titanic")

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
data["pclass"]
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: pclass, Length: 891, dtype: int64

# %%
data["sex"].str.isnumeric()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: sex, Length: 891, dtype: bool

# %%
data[data["sex"].str.isnumeric()]
# Out:
# Empty DataFrame
# Columns: [survived, pclass, sex, age, sibsp, parch, fare, embarked, class, who, adult_male, deck, embark_town, alive, alone]
# Index: []

# %%
data[data.dtypes.index[data.dtypes=='object']]
# Out:
#         sex embarked    who  embark_town alive
# 0      male        S    man  Southampton    no
# 1    female        C  woman    Cherbourg   yes
# 2    female        S  woman  Southampton   yes
# 3    female        S  woman  Southampton   yes
# 4      male        S    man  Southampton    no
# ..      ...      ...    ...          ...   ...
# 886    male        S    man  Southampton    no
# 887  female        S  woman  Southampton   yes
# 888  female        S  woman  Southampton    no
# 889    male        C    man    Cherbourg   yes
# 890    male        Q    man   Queenstown    no
#
# [891 rows x 5 columns]

# %%
sns.load_dataset("iris")
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data.corr()
# Out:
# <ipython-input-21-c44ded798807>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# ...

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
data.groupby("sex")[["age"]].mean()
# Out:
#               age
# sex
# female  27.915709
# male    30.726645

# %%
data[data.duplicated("sex")]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# 6           0       1    male  54.0      0      0  51.8625        S   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data.drop_duplicates(subset="age",keep="first")
# Out:
#      survived  pclass     sex    age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.00      1      0   7.2500        S   Third
# 1           1       1  female  38.00      1      0  71.2833        C   First
# 2           1       3  female  26.00      0      0   7.9250        S   Third
# 3           1       1  female  35.00      1      0  53.1000        S   First
# 5           0       3    male    NaN      0      0   8.4583        Q   Third
# ..        ...     ...     ...    ...    ...    ...      ...      ...     ...
# 755         1       2    male   0.67      1      1  14.5000        S  Second
# 767         0       3  female  30.50      0      0   7.7500        Q   Third
# 803         1       3    male   0.42      0      1   8.5167        C   Third
# 843         0       3    male  34.50      0      0   6.4375        C   Third
# 851         0       3    male  74.00      0      0   7.7750        S   Third
#
# ...

# %%
data.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
[i for i in data.dtypes if i=='int64']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-ab8480fbe322> in <cell line: 1>()
# ----> 1 [i.column for i in data.dtypes if i=='int64']
#
# <ipython-input-40-ab8480fbe322> in <listcomp>(.0)
# ----> 1 [i.column for i in data.dtypes if i=='int64']
#
# AttributeError: 'numpy.dtype[int64]' object has no attribute 'column'

# %%
data.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
[i for i in data.columns if data[i].dtype=="bool"]
# Out:
# ['adult_male', 'alone']

# %%
data["sex"].value_counts()
# Out:
# male      577
# female    314
# Name: sex, dtype: int64

# %%
data["sex"].value_counts(normalize=True)
# Out:
# male      0.647587
# female    0.352413
# Name: sex, dtype: float64

# %%
data["sex"].value_counts(normalize=True)*100
# Out:
# male      64.758698
# female    35.241302
# Name: sex, dtype: float64

# %%
import pandas as pd

# %%
pd.read_csv("https://github.com/sunnysavita10/Statistics-With-Python-TheCompleteGuide/blob/main/googleplaystore.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-2-d8f23da9073f> in <cell line: 1>()
# ----> 1 pd.read_csv("https://github.com/sunnysavita10/Statistics-With-Python-TheCompleteGuide/blob/main/googleplaystore.csv")
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
import seaborn as sns

# %%
data=sns.load_dataset("titanic")

# %%
sns.countplot(x=data["sex"])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.kdeplot(["sex"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-993863d7dfb4> in <cell line: 1>()
# ----> 1 sns.kdeplot(["sex"])
#
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py in kdeplot(data, x, y, hue, weights, palette, hue_order, hue_norm, color, fill, multiple, common_norm, common_grid, cumulative, bw_method, bw_adjust, warn_singular, log_scale, levels, thresh, gridsize, cut, clip, legend, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#    1693         ax = plt.gca()
#    1694
# -> 1695     p._attach(ax, allowed_types=["numeric", "datetime"], log_scale=log_scale)
#    1696
#    1697     method = ax.fill_between if fill else ax.plot
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py in _attach(self, obj, allowed_types, log_scale)
#    1209                     f"{allowed_types} is required"
#    1210                 )
# ...

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.kdeplot(data["pclass"])
# Out:
# <Axes: xlabel='pclass', ylabel='Density'>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
sns.kdeplot(data["age"])
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.histplot(data["sex"])
# Out:
# <Axes: xlabel='sex', ylabel='Count'>

# %%
data["embark_town"].value_counts().plot()
# Out:
# <Axes: >

# %%
data["embark_town"].value_counts().plot.pie(x=["embark_town"],figsize=(15,15))
# Out:
# <Axes: ylabel='embark_town'>

# %%
data["embark_town"].value_counts()
# Out:
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: embark_town, dtype: int64

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
data.groupby("embark_town")["fare"].sum().sort_values(ascending=False)
# Out:
# embark_town
# Southampton    17439.3988
# Cherbourg      10072.2962
# Queenstown      1022.2543
# Name: fare, dtype: float64

# %%
top_fare_townwise=data.groupby("embark_town")["fare"].sum().sort_values(ascending=False).reset_index()

# %%
top_fare_townwise
# Out:
#    embark_town        fare
# 0  Southampton  17439.3988
# 1    Cherbourg  10072.2962
# 2   Queenstown   1022.2543

# %%
sns.distplot(x=["fare"])
# Out:
# <ipython-input-38-ae3c0b1ba04c>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=["fare"])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-ae3c0b1ba04c> in <cell line: 1>()
# ----> 1 sns.distplot(x=["fare"])
#
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
#    2456
#    2457     # Make a a 1-d float array
# -> 2458     a = np.asarray(a, float)
# ...

# %%
count_fare_townwise=data.groupby("embark_town")["fare"].count().sort_values(ascending=False).reset_index()

# %%
count_fare_townwise
# Out:
#    embark_town  fare
# 0  Southampton   644
# 1    Cherbourg   168
# 2   Queenstown    77

# %%
sns.barplot(x="fare",y="embark_town",data=count_fare_townwise)
# Out:
# <Axes: xlabel='fare', ylabel='embark_town'>

# %%
data.groupby(["embark_town","sex"])["fare"].count().sort_values(ascending=False).reset_index()
# Out:
#    embark_town     sex  fare
# 0  Southampton    male   441
# 1  Southampton  female   203
# 2    Cherbourg    male    95
# 3    Cherbourg  female    73
# 4   Queenstown    male    41
# 5   Queenstown  female    36

# %%
import numpy as np
from statistics import mode

# %%
np.random.randint(1,10,15)
# Out:
# array([7, 8, 1, 1, 5, 1, 6, 9, 1, 1, 6, 5, 5, 5, 6])

# %%
population=np.random.randint(1,10,15)
print(population)
# Out:
# [2 2 6 1 1 8 6 2 3 9 6 4 5 5 2]

# %%
np.mean(population)
# Out:
# 4.133333333333334

# %%
np.median(population)
# Out:
# 4.0

# %%
mode(population)
# Out:
# 2

# %%
np.random.choice(population,5)
# Out:
# array([6, 6, 1, 1, 2])

# %%
sample=np.random.choice(population,5)

# %%
sample
# Out:
# array([6, 9, 1, 6, 9])

# %%
np.mean(sample)
# Out:
# 6.2

# %%
np.median(sample)
# Out:
# 6.0

# %%
mode(sample)
# Out:
# 6

# %%
np.random.binomial(10,0.5,10)
# Out:
# array([5, 5, 5, 6, 5, 5, 7, 6, 4, 7])

# %%
import seaborn as sns

# %%
sns.distplot(np.random.binomial(10,0.5,10),kde=True)
# Out:
# <ipython-input-32-1bf81ec739fe>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.random.binomial(10,0.5,10),kde=True)
# <Axes: ylabel='Density'>

# %%
sns.distplot(np.random.binomial(10,0.5,1000),kde=True)
# Out:
# <ipython-input-33-c585c6731044>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.random.binomial(10,0.5,1000),kde=True)
# <Axes: ylabel='Density'>

# %%
data=np.random.binomial(10,0.5,1000)

# %%
len(data)
# Out:
# 1000

# %%
sample_mean=[]
for i in range(1,31):
  print(np.random.choice(data,size=int(len(data)*0.3)))
# Out:
# [5 3 4 5 6 3 5 5 4 6 5 3 4 5 4 3 6 6 3 6 6 7 3 6 6 4 6 6 8 5 6 4 3 3 8 3 4
#  4 6 4 4 3 4 5 4 5 7 5 5 8 8 7 2 7 6 9 4 4 7 5 4 3 6 3 5 4 4 4 4 8 3 4 6 5
#  4 7 4 7 3 6 6 3 2 2 4 4 7 5 5 9 4 7 5 5 3 3 3 4 6 4 8 4 6 6 5 3 8 8 6 7 4
#  8 7 4 6 4 6 4 7 5 6 5 6 3 8 4 7 7 8 5 6 3 4 6 6 7 6 3 4 6 4 5 4 6 7 4 5 4
#  6 4 7 2 4 6 4 5 5 4 6 2 3 7 4 6 6 5 3 8 7 6 5 5 5 3 5 4 7 5 6 5 4 6 6 7 5
#  4 4 4 5 3 4 4 4 2 6 6 6 3 4 3 3 3 6 2 5 7 3 6 6 7 6 4 5 7 4 4 8 6 7 3 6 9
#  7 6 4 4 8 4 4 3 3 6 7 6 6 4 5 4 4 2 4 7 8 6 4 7 7 5 7 1 3 7 5 6 7 5 8 6 4
#  8 5 5 3 5 7 4 4 1 3 6 5 7 6 6 4 4 5 3 4 4 6 5 5 6 3 5 5 4 8 7 4 4 6 8 6 6
#  4 5 4 6]
# [3 6 4 6 7 3 6 3 4 6 5 5 5 5 4 4 4 7 6 7 4 4 6 7 4 5 1 4 4 7 4 4 5 5 4 6 5
#  4 4 3 6 7 7 6 3 6 6 4 6 5 1 6 3 4 7 6 3 3 6 5 4 6 1 4 3 5 6 5 4 5 3 3 5 4
#  6 4 5 9 4 6 7 3 4 6 6 4 4 6 4 5 6 8 7 6 4 5 3 6 5 6 5 2 4 3 6 3 5 4 7 2 5
#  7 7 4 6 5 4 6 8 4 6 6 5 5 4 5 6 7 4 5 6 5 5 3 5 4 5 6 7 6 3 6 5 6 5 6 4 6
# ...

# %%
sample_mean=[]
for i in range(1,31):
  sample=(np.random.choice(data,size=int(len(data)*0.3)))
  sample_mean.append(np.mean(sample))

# %%
sample_mean
# Out:
# [4.883333333333334,
#  4.93,
#  4.97,
#  4.98,
#  5.08,
#  4.846666666666667,
#  4.976666666666667,
#  5.053333333333334,
#  4.8933333333333335,
#  5.193333333333333,
#  5.083333333333333,
#  5.153333333333333,
#  5.016666666666667,
#  4.973333333333334,
#  4.97,
#  4.986666666666666,
#  5.09,
#  4.966666666666667,
#  5.083333333333333,
#  4.8966666666666665,
#  4.903333333333333,
#  5.076666666666667,
#  4.986666666666666,
#  4.996666666666667,
#  5.06,
#  5.04,
#  4.956666666666667,
#  5.06,
#  5.05,
#  5.076666666666667]

# %%
sns.distplot(sample_mean)  #Central linit theroem proved
# Out:
# <ipython-input-48-d196905dea46>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sample_mean)
# <Axes: ylabel='Density'>

# %%
sample_mean=[]
for i in range(1,500):
  sample=(np.random.choice(data,size=int(len(data)*0.3)))
  sample_mean.append(np.mean(sample))

# %%
sns.distplot(sample_mean,kde=True,color="red")  #Central linit theroem proved with sample size=500
# Out:
# <ipython-input-51-353199989a1f>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sample_mean,kde=True,color="red")  #Central linit theroem proved with sample size=500
# <Axes: ylabel='Density'>

# %%
import scipy.stats as stats

# %%
stats.norm.ppf(q=0.95) #area under the curve with 95%confidence interval, Standrad normal distribution
# Out:
# 1.6448536269514722

# %%
stats.norm.ppf(q=0.975) #Z score or area under the curve
# Out:
# 1.959963984540054

# %%
stats.t.ppf(q=0.975,df=24) #Z score or area under the curve
# Out:
# 2.0638985616280205

# %%
np.random.randn(50)
# Out:
# array([ 3.78587930e-01, -2.76240000e-01,  1.67472379e+00,  2.26656641e+00,
#        -3.27755960e+00,  5.90570100e-01,  2.09960098e-01,  5.88452419e-02,
#         5.78169661e-01,  1.41599003e+00, -1.78674091e-01,  2.54460389e+00,
#         2.27813627e+00, -8.05661664e-01, -1.08772297e+00,  2.37415135e-01,
#        -4.73116968e-01, -5.25114859e-01, -9.52063321e-01,  9.02473306e-01,
#         2.07422430e+00,  4.15710663e-01,  1.55852078e+00, -2.07057720e-03,
#         2.71173638e-01,  8.06889638e-01, -1.35516334e+00,  3.77444572e-01,
#        -7.08837140e-01,  5.32105984e-01, -4.26835064e-01, -6.89007371e-01,
#        -4.29269771e-01,  5.49083195e-01,  2.22601005e+00, -1.66965081e+00,
#         1.52457325e+00, -1.17622181e+00,  3.34768151e-01,  4.02866459e-01,
#         2.40447239e-01, -1.07300577e+00, -1.99184332e+00,  1.42769876e+00,
#         8.12957891e-02,  1.14458452e+00,  7.73080634e-01, -1.03266431e+00,
#        -5.81733352e-01,  9.07518112e-01])

# %%
import seaborn as sns

# %%
data=sns.load_dataset("tips")

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
data["tip"]
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
sns.distplot(data["tip"])
# Out:
# <ipython-input-5-e11ea6633e25>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["tip"])
# <Axes: xlabel='tip', ylabel='Density'>

# %%
import numpy as np

# %%
sns.distplot(np.log(data["tip"]),kde=True,color="red")
# Out:
# <ipython-input-9-112fe9d07af7>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(data["tip"]),kde=True,color="red")
# <Axes: xlabel='tip', ylabel='Density'>

# %%
#how to check normality (Shepero wilk test)
import scipy

# %%
scipy.stats.shapiro(data["tip"])  #p>0.05 the normal dist
# Out:
# ShapiroResult(statistic=0.8978114128112793, pvalue=8.200817629144819e-12)

# %%
scipy.stats.shapiro(np.log(data["tip"]))
# Out:
# ShapiroResult(statistic=0.9888470768928528, pvalue=0.056213147938251495)

# %%
np.random.randint(0,15,10)
# Out:
# array([ 2, 10, 11, 10,  8,  6,  2, 12, 12,  3])

# %%
sns.distplot(np.random.randint(0,15,10))
# Out:
# <ipython-input-19-14e892014a10>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.random.randint(0,15,10))
# <Axes: ylabel='Density'>

# %%
scipy.stats.shapiro(np.random.randint(0,15,10)) #P>0.05 so normal dist
# Out:
# ShapiroResult(statistic=0.9534962773323059, pvalue=0.7099277377128601)

# %%
sns.distplot(np.random.randn(500))
# Out:
# <ipython-input-25-7973a3203966>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.random.randn(500))
# <Axes: ylabel='Density'>

# %%
scipy.stats.shapiro(np.random.randn(500)) #P>0.05 so normal dist
# Out:
# ShapiroResult(statistic=0.9980301856994629, pvalue=0.8387413024902344)

# %%
scipy.stats.normaltest(np.random.randn(500))  #normal test 2nd one
# Out:
# NormaltestResult(statistic=0.011451787459892719, pvalue=0.9942904679562363)

# %%
from statsmodels.stats.weightstats import ztest

statsmodels.stats.weightstats.ztest(np.random.randn(500),value=0,alternative="larger") #null=0 because nprmal dist it is, So we are etting >0.05
# Out:
# (-1.5577832150222237, 0.9403576768811049)

# %%
import seaborn as sns
import pandas as pd

# %%
data=sns.load_dataset("tips")

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
pd.crosstab(data["sex"],data["time"])
# Out:
# time    Lunch  Dinner
# sex
# Male       33     124
# Female     35      52

# %%
crosstab_table=pd.crosstab(data["sex"],data["time"])

# %%
crosstab_table
# Out:
# time    Lunch  Dinner
# sex
# Male       33     124
# Female     35      52

# %%
crosstab_table.values
# Out:
# array([[ 33, 124],
#        [ 35,  52]])

# %% [markdown]
# ##Web Scrapping

# %%
search_string="iphone"

# %%
Flipcart_url="https://www.flipkart.com/search?q=" + search_string

# %%
print(Flipcart_url)
# Out:
# https://www.flipkart.com/search?q=iphone
