# %%
f=open("mytxt.txt","r")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-49-d9049147865d> in <cell line: 1>()
# ----> 1 f=open("mytxt.txt","r")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'mytxt.txt'
