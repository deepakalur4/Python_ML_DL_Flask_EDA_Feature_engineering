# %%
with open("Deepak.txt","w") as f:
  f.write("Deepak is a good boy")
  f.truncate(10)

# %%
with open("Deepak.txt","r") as f:
  # f.seek(10)
  print(f.tell())

  print(f.read())
# Out:
# 0
# Deepak is

# %%
a=lambda c:c*5

# %%
a(2)
# Out:
# 10

# %%
(print(lambda c:c*5))
# Out:
# <function <lambda> at 0x7806f8138820>
