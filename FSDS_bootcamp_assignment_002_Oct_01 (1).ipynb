# %% [markdown]
# # ASSIGNMENTS - Compulsory
# ## Send it before 0000 hrs IST or 12 AM Wednesday
#
# ## NOTE: Evaluation will be done before next class.
#
# ## HOW TO SUBMIT: -
# Download this notebook, Solve it and upload in the google form given in the mail.

# %% [markdown]
# 1. **What is indentation error? Why indentation is important? Give one simple example?**
#
#   -The indentation error is the type of error in python which will be caused if there is mis match between the spaces in between the block of codes.
#
#   -**Why indentation is important**-
#
#   -The indentation is important in python because the python uses indentation to indicate a block of code, Interpreter will get confused which line of code belongs to which block if there is mismatch between the block of codes.

# %%
#Simple example:-
a,b=10,20
if a==b:
  print(f'a:{a} has same values as b:{b}')
elif a>b:
print(f'a:{a} is greater than b:{b}') #Throws an error because interpreter is getting confused this print belong to which code block.
else:
  print(f'a:{a} is lesser than b:{b}')
# Out:
#   File "<ipython-input-18-a3ea881a7b7d>", line 5
#     print(f'a:{a} is greater than b:{b}') #Throws an error because interpreter is getting confused this print belong to which code block.
#         ^
# IndentationError: expected an indented block

# %% [markdown]
# 2. Correct the following code and write the comment where you made the correction?
#
#   ```python
#   class_started = bool(input("Hey friend, is class started?: [0-False/1-True]"))
#
#   if class_started:
#       print("Since class started...")
#       print("Lets concentrate")
#   else:
#       print("Since class is not started...")
#       print("let's revise")
#   ```
#
#   **HINT:** Refer your data type conversion class

# %%
  #Solution 
  class_started = bool(int(input("Hey friend, is class started?: [0-False/1-True]"))) #The integer type casting is necessary while taking the input as the data type of input function is always String, Now it will give the correct output for both the cases, Earlier it was cosidering every input as True("anything") because of string Values so only first true statement was executing all the time.

  if class_started:
      print("Since class started...")
      print("Lets concentrate")
  else:
      print("Since class is not started...")
      print("let's revise")
# Out:
# Hey friend, is class started?: [0-False/1-True]0
# Since class is not started...
# let's revise

# %% [markdown]
# 3. Use if else condition to verify that dataype of `input()` method in python is always string.

# %%
user_input=input("Please Enter the Numeric value: ") #Int Type casting is neccessary

if type(user_input)==int:
    print(user_input//5)
else:
  print(f"The Data type of user_input is : {type(user_input)}")
# Out:
# Please Enter the Numeric value: 5
# The Data type of user_input is : <class 'str'>

# %% [markdown]
# 4. Take 3 variables and assign integer values to them. Find the largest variable, by only using the if and else conditions.

# %%
a,b,c=100,45,30
if (a>=b and a>=c):
  print("a is largest")
elif (b>=a and b>=c):
  print("b is largest")
else:
  print("c is largest")
# Out:
# a is largest

# %% [markdown]
# 5. What would be the solution?
#     1. True
#     2. False
#
#    ~~~python
#     a = 6
#     b = 10
#     print( not ( not a == 10 or not b == 10) )
#   ~~~
#   **Solution-False**

# %% [markdown]
#  6. Find the answer as well as find out the reason behind the result? -

# %%
#case 1:
A = 5.0
B = 10/2
print(A is B)

print(A,B) 
print(id(A)) 
print(id(B))#Since variable B is dynamic assignment as we can change 10 to any value in future hence its allocating diffrent address to B, Not same as A even if both the final same end value
# Out:
# False
# 5.0 5.0
# 140626567560496
# 140626567557296

# %%
#case 1:
  A = 5.0
  B = int(10/2)
  print(A is B)
        
print(A,B) 
print(id(A),type(A)) 
print(id(B),type(B)) #A is integer value because of which its assigning diffrent memory address or location
# Out:
# False
# 5.0 5
# 140626567561104 <class 'float'>
# 11122720 <class 'int'>

# %%
#case 3:
A = 5.0
B = float(10/2)
print(A is B)
print(A,B) 
print(id(A)) 
print(id(B))#Since variable B is dynamic assignment as we can change 10 to any value in future hence its allocating diffrent address to B, Not same as A even if both the final same end value
# Out:
# False
# 5.0 5.0
# 140626567244592
# 140626567558384

# %% [markdown]
# ### Try to understand the following examples and answer the question based on it -
#
# **Arithmatic Operators**
#
# |Operation|Meaning|
# |:-:|:-:|
# | **+** |addition|
# | **-** |subtraction|
# | **\*** |multiplication|
# | **/** |true division|
# | **//** |integer division|
# | **%** |the modulo operator|
#
#
# Here `+`, `-`, `*`, `/` are regular arithmatic operators. Lets look at the `//` and `%` operators
#
# Usecase or examples -
#
# ```python
# var_a = 5
# var_b = 25
# integer_division = var_b // var_a
# print(f"integer division: {var_b}/{var_a}={integer_division}")
# ```
#
# OUTPUT: integer division: 25/5=5
#
# ```python
# var_a = 3
# var_b = 25
# integer_division = var_b // var_a
# print(f"integer division: {var_b}/{var_a}={integer_division}")
# ```
#
# OUTPUT: integer division: 25/3=8
#
# ```python
# var_a = 5
# var_b = 25
# remainder = var_b % var_a
# print(f"remainder: {var_b}/{var_a} is {remainder}")
# ```
#
# OUTPUT: remainder: 25/5 is 0
#
# ```python
# var_a = 3
# var_b = 25
# remainder = var_b % var_a
# print(f"remainder: {var_b}/{var_a} is {remainder}")
# ```
#
# OUTPUT: remainder: 25/3 is 1

# %% [markdown]
# ### Answer below questions on the above theory -
#
# 7. Write a program that asks the user to enter a number. You should print out a message to the user, either “That number is divisible by either 3 or 5”, or “That number is not divisible by either 3 or 5”. Be sure to consider the data type of the input you are taking in from the user. Use a single if/else block to solve this problem.

# %%
User_input=int(input("Please Enter the number: "))
if (User_input%3==0 or User_input%5==0):
  print("The number is divisible by either 3 or 5")
else:
  print("The number is not divisible by either 3 or 5")
# Out:
# Please Enter the number: 14
# The number is not divisible by either 3 or 5

# %% [markdown]
# 8. Take user input for length and width. Then calculate the area of rectangle. Also print as per length and width whether its a square of rectangle.

# %%
len=int(input("Please Enter the length in CM: "))
width=int(input("Please Enter the width in CM : "))
if (len==width):
  print(f"Its the Squre as length {len}CM is Equal to width {width}CM")
else:
  print(f'''The length of the rectangle is : {len}CM
The width of the rectangle is : {width}CM
The Area of the rectangle is {len*width}CM''')
# Out:
# Please Enter the length in CM: 4
# Please Enter the width in CM : 5
# The length of the rectangle is : 4CM
# The width of the rectangle is : 5CM
# The Area of the rectangle is 20CM

# %% [markdown]
# 9. Take two variable radius_1 and radius_2 and calculate the area of circle_1 and circle_2. Also print which circle has large area. If area is equal then print area is equal.

# %%
radius_1,radius_2=10,20
area_of_circle_1=3.142*(radius_1*radius_1)
area_of_circle_2=3.142*(radius_2*radius_2)
print(f"The area of Circle_1 is : {area_of_circle_1}, The area_of_circle_2 is : {area_of_circle_2}")
if area_of_circle_1==area_of_circle_2:
  print(f"Both the circles has same area area_of_circle_1:{area_of_circle_1},area_of_circle_2: {area_of_circle_1}")
elif area_of_circle_1>area_of_circle_2:
  print("Area of circle_1 is greater than Area of circle_2")
else:
  print("Area of circle_2 is greater than Area of circle_21")
# Out:
# The area of Circle_1 is : 314.2, The area_of_circle_2 is : 1256.8
# Area of circle_2 is greater than Area of circle_21

# %% [markdown]
# 10. Check whether a year is leap year or not. Use nested if...else to solve this problem. A leap year is exactly divisible by 4 except for century years (years ending with 00). The century year is a leap year only if it is perfectly divisible by 400.

# %%
year=int(input("Please enter the year: "))
if (year%4==0):
  if (year%100==0):
    if (year%400==0):
      print("its the leap year")
    else:
      print("Its not a leap year")
  else:
    print("Its a leap year")
else:
  print("its not a leap year")
# Out:
# Please enter the year: 2024
# Its a leap year
