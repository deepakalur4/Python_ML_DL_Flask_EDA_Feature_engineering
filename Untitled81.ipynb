# %%
from pymongo.mongo_client import MongoClient
uri = "mongodb+srv://deepak:1234@cluster0.6t1mv.mongodb.net/?retryWrites=true&w=majority"
# Create a new client and connect to the server
client = MongoClient(uri)

# %%
database=client["customers"]

# %%
coll=database["orders"]

# %%
data={
    "Name":"Deepak",
    "age":28,
    "interests":["Playing cricket","Hockey","Dj"]

}

# %%
coll.insert_one(data)
# Out:
# InsertOneResult(ObjectId('65d45a5a41486eb8c40adb67'), acknowledged=True)

# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv")

# %%
rec=df.to_dict("records")

# %%
coll.insert_many(rec)
# Out:
# InsertManyResult([ObjectId('65d45aa841486eb8c40adb68'), ObjectId('65d45aa841486eb8c40adb69'), ObjectId('65d45aa841486eb8c40adb6a'), ObjectId('65d45aa841486eb8c40adb6b'), ObjectId('65d45aa841486eb8c40adb6c'), ObjectId('65d45aa841486eb8c40adb6d'), ObjectId('65d45aa841486eb8c40adb6e'), ObjectId('65d45aa841486eb8c40adb6f'), ObjectId('65d45aa841486eb8c40adb70'), ObjectId('65d45aa841486eb8c40adb71'), ObjectId('65d45aa841486eb8c40adb72'), ObjectId('65d45aa841486eb8c40adb73'), ObjectId('65d45aa841486eb8c40adb74'), ObjectId('65d45aa841486eb8c40adb75'), ObjectId('65d45aa841486eb8c40adb76'), ObjectId('65d45aa841486eb8c40adb77'), ObjectId('65d45aa841486eb8c40adb78'), ObjectId('65d45aa841486eb8c40adb79'), ObjectId('65d45aa841486eb8c40adb7a'), ObjectId('65d45aa841486eb8c40adb7b'), ObjectId('65d45aa841486eb8c40adb7c'), ObjectId('65d45aa841486eb8c40adb7d'), ObjectId('65d45aa841486eb8c40adb7e'), ObjectId('65d45aa841486eb8c40adb7f'), ObjectId('65d45aa841486eb8c40adb80'), ObjectId('65d45aa841486eb8c40a
# ...

# %%
rec=coll.find()

# %%
for i in rec:
  print(i)
# Out:
# {'_id': ObjectId('65d45a5a41486eb8c40adb67'), 'Name': 'Deepak', 'age': 28, 'interests': ['Playing cricket', 'Hockey', 'Dj']}
# {'_id': ObjectId('65d45aa841486eb8c40adb68'), 'sepal_length': 5.1, 'sepal_width': 3.5, 'petal_length': 1.4, 'petal_width': 0.2, 'species': 'setosa'}
# {'_id': ObjectId('65d45aa841486eb8c40adb69'), 'sepal_length': 4.9, 'sepal_width': 3.0, 'petal_length': 1.4, 'petal_width': 0.2, 'species': 'setosa'}
# {'_id': ObjectId('65d45aa841486eb8c40adb6a'), 'sepal_length': 4.7, 'sepal_width': 3.2, 'petal_length': 1.3, 'petal_width': 0.2, 'species': 'setosa'}
# {'_id': ObjectId('65d45aa841486eb8c40adb6b'), 'sepal_length': 4.6, 'sepal_width': 3.1, 'petal_length': 1.5, 'petal_width': 0.2, 'species': 'setosa'}
# {'_id': ObjectId('65d45aa841486eb8c40adb6c'), 'sepal_length': 5.0, 'sepal_width': 3.6, 'petal_length': 1.4, 'petal_width': 0.2, 'species': 'setosa'}
# ...

# %%
from pprint import pprint

# %%
for i in rec:
  pprint(i)
# Out:
# {'Name': 'Deepak',
#  '_id': ObjectId('65d45a5a41486eb8c40adb67'),
#  'age': 28,
#  'interests': ['Playing cricket', 'Hockey', 'Dj']}
# {'_id': ObjectId('65d45aa841486eb8c40adb68'),
#  'petal_length': 1.4,
#  'petal_width': 0.2,
#  'sepal_length': 5.1,
#  'sepal_width': 3.5,
#  'species': 'setosa'}
# {'_id': ObjectId('65d45aa841486eb8c40adb69'),
#  'petal_length': 1.4,
#  'petal_width': 0.2,
#  'sepal_length': 4.9,
#  'sepal_width': 3.0,
#  'species': 'setosa'}
# {'_id': ObjectId('65d45aa841486eb8c40adb6a'),
#  'petal_length': 1.3,
#  'petal_width': 0.2,
#  'sepal_length': 4.7,
#  'sepal_width': 3.2,
#  'species': 'setosa'}
# {'_id': ObjectId('65d45aa841486eb8c40adb6b'),
#  'petal_length': 1.5,
#  'petal_width': 0.2,
#  'sepal_length': 4.6,
#  'sepal_width': 3.1,
#  'species': 'setosa'}
# {'_id': ObjectId('65d45aa841486eb8c40adb6c'),
#  'petal_length': 1.4,
#  'petal_width': 0.2,
#  'sepal_length': 5.0,
#  'sepal_width': 3.6,
#  'species': 'setosa'}
# ...

# %%
coll.find_one()
# Out:
# {'_id': ObjectId('65d45a5a41486eb8c40adb67'),
#  'Name': 'Deepak',
#  'age': 28,
#  'interests': ['Playing cricket', 'Hockey', 'Dj']}

# %%
rec_1=coll.find({},{"sepal_width"})

# %%
for i in rec_1:print(i)
# Out:
# {'_id': ObjectId('65d45a5a41486eb8c40adb67')}
# {'_id': ObjectId('65d45aa841486eb8c40adb68'), 'sepal_width': 3.5}
# {'_id': ObjectId('65d45aa841486eb8c40adb69'), 'sepal_width': 3.0}
# {'_id': ObjectId('65d45aa841486eb8c40adb6a'), 'sepal_width': 3.2}
# {'_id': ObjectId('65d45aa841486eb8c40adb6b'), 'sepal_width': 3.1}
# {'_id': ObjectId('65d45aa841486eb8c40adb6c'), 'sepal_width': 3.6}
# {'_id': ObjectId('65d45aa841486eb8c40adb6d'), 'sepal_width': 3.9}
# {'_id': ObjectId('65d45aa841486eb8c40adb6e'), 'sepal_width': 3.4}
# {'_id': ObjectId('65d45aa841486eb8c40adb6f'), 'sepal_width': 3.4}
# {'_id': ObjectId('65d45aa841486eb8c40adb70'), 'sepal_width': 2.9}
# {'_id': ObjectId('65d45aa841486eb8c40adb71'), 'sepal_width': 3.1}
# {'_id': ObjectId('65d45aa841486eb8c40adb72'), 'sepal_width': 3.7}
# {'_id': ObjectId('65d45aa841486eb8c40adb73'), 'sepal_width': 3.4}
# {'_id': ObjectId('65d45aa841486eb8c40adb74'), 'sepal_width': 3.0}
# {'_id': ObjectId('65d45aa841486eb8c40adb75'), 'sepal_width': 3.0}
# ...

# %%
for i in coll.find({"sepal_width":3.8}):
  print(i)
# Out:
# {'_id': ObjectId('65d45aa841486eb8c40adb7a'), 'sepal_length': 5.7, 'sepal_width': 3.8, 'petal_length': 1.7, 'petal_width': 0.3, 'species': 'setosa'}
# {'_id': ObjectId('65d45aa841486eb8c40adb7b'), 'sepal_length': 5.1, 'sepal_width': 3.8, 'petal_length': 1.5, 'petal_width': 0.3, 'species': 'setosa'}
# {'_id': ObjectId('65d45aa841486eb8c40adb94'), 'sepal_length': 5.1, 'sepal_width': 3.8, 'petal_length': 1.9, 'petal_width': 0.4, 'species': 'setosa'}
# {'_id': ObjectId('65d45aa841486eb8c40adb96'), 'sepal_length': 5.1, 'sepal_width': 3.8, 'petal_length': 1.6, 'petal_width': 0.2, 'species': 'setosa'}
# {'_id': ObjectId('65d45aa841486eb8c40adbdd'), 'sepal_length': 7.7, 'sepal_width': 3.8, 'petal_length': 6.7, 'petal_width': 2.2, 'species': 'virginica'}
# {'_id': ObjectId('65d45aa841486eb8c40adbeb'), 'sepal_length': 7.9, 'sepal_width': 3.8, 'petal_length': 6.4, 'petal_width': 2.0, 'species': 'virginica'}

# %%
for i in coll.find():
  print(i)
# Out:
# {'_id': ObjectId('65d45a5a41486eb8c40adb67'), 'Name': 'Deepak', 'age': 28, 'interests': ['Playing cricket', 'Hockey', 'Dj']}
# {'_id': ObjectId('65d45aa841486eb8c40adb68'), 'sepal_length': 5.1, 'sepal_width': 3.5, 'petal_length': 1.4, 'petal_width': 0.2, 'species': 'setosa'}
# {'_id': ObjectId('65d45aa841486eb8c40adb69'), 'sepal_length': 4.9, 'sepal_width': 3.0, 'petal_length': 1.4, 'petal_width': 0.2, 'species': 'setosa'}
# {'_id': ObjectId('65d45aa841486eb8c40adb6a'), 'sepal_length': 4.7, 'sepal_width': 3.2, 'petal_length': 1.3, 'petal_width': 0.2, 'species': 'setosa'}
# {'_id': ObjectId('65d45aa841486eb8c40adb6b'), 'sepal_length': 4.6, 'sepal_width': 3.1, 'petal_length': 1.5, 'petal_width': 0.2, 'species': 'setosa'}
# {'_id': ObjectId('65d45aa841486eb8c40adb6c'), 'sepal_length': 5.0, 'sepal_width': 3.6, 'petal_length': 1.4, 'petal_width': 0.2, 'species': 'setosa'}
# ...

# %%
coll.update_many({"sepal_length":6.1},{"$set":{"sepal_length":1000}})
# Out:
# UpdateResult({'n': 5, 'electionId': ObjectId('7fffffff0000000000000004'), 'opTime': {'ts': Timestamp(1708417108, 14), 't': 4}, 'nModified': 5, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1708417108, 14), 'signature': {'hash': b'y<\x06j\x91\xd0]/\xdd\xcb\xad\x94\x19\\X\xb9K\xe7\xb5\xc9', 'keyId': 7336885283620651013}}, 'operationTime': Timestamp(1708417108, 14), 'updatedExisting': True}, acknowledged=True)

# %%
for i in coll.find({"sepal_length":1000}):
  print(i)
# Out:
# {'_id': ObjectId('65d45aa841486eb8c40adba7'), 'sepal_length': 1000, 'sepal_width': 2.9, 'petal_length': 4.7, 'petal_width': 1.4, 'species': 'versicolor'}
# {'_id': ObjectId('65d45aa841486eb8c40adbaf'), 'sepal_length': 1000, 'sepal_width': 2.8, 'petal_length': 4.0, 'petal_width': 1.3, 'species': 'versicolor'}
# {'_id': ObjectId('65d45aa841486eb8c40adbb1'), 'sepal_length': 1000, 'sepal_width': 2.8, 'petal_length': 4.7, 'petal_width': 1.2, 'species': 'versicolor'}
# {'_id': ObjectId('65d45aa841486eb8c40adbc3'), 'sepal_length': 1000, 'sepal_width': 3.0, 'petal_length': 4.6, 'petal_width': 1.4, 'species': 'versicolor'}
# {'_id': ObjectId('65d45aa841486eb8c40adbe7'), 'sepal_length': 1000, 'sepal_width': 3.0, 'petal_length': 4.9, 'petal_width': 1.8, 'species': 'virginica'}
# {'_id': ObjectId('65d45aa841486eb8c40adbee'), 'sepal_length': 1000, 'sepal_width': 2.6, 'petal_length': 5.6, 'petal_width': 1.4, 'species': 'virginica'}

# %%
for i in coll.find({"petal_length":{"$gt":5.0}}):
  print(i)
# Out:
# {'_id': ObjectId('65d45aa841486eb8c40adbbb'), 'sepal_length': 6.0, 'sepal_width': 2.7, 'petal_length': 5.1, 'petal_width': 1.6, 'species': 'versicolor'}
# {'_id': ObjectId('65d45aa841486eb8c40adbcc'), 'sepal_length': 6.3, 'sepal_width': 3.3, 'petal_length': 6.0, 'petal_width': 2.5, 'species': 'virginica'}
# {'_id': ObjectId('65d45aa841486eb8c40adbcd'), 'sepal_length': 5.8, 'sepal_width': 2.7, 'petal_length': 5.1, 'petal_width': 1.9, 'species': 'virginica'}
# {'_id': ObjectId('65d45aa841486eb8c40adbce'), 'sepal_length': 7.1, 'sepal_width': 3.0, 'petal_length': 5.9, 'petal_width': 2.1, 'species': 'virginica'}
# {'_id': ObjectId('65d45aa841486eb8c40adbcf'), 'sepal_length': 6.3, 'sepal_width': 2.9, 'petal_length': 5.6, 'petal_width': 1.8, 'species': 'virginica'}
# {'_id': ObjectId('65d45aa841486eb8c40adbd0'), 'sepal_length': 6.5, 'sepal_width': 3.0, 'petal_length': 5.8, 'petal_width': 2.2, 'species': 'virginica'}
# ...

# %%
for i in coll.find({"petal_length":{"$lt":5.0}}):
  print(i)
# Out:
# {'_id': ObjectId('65d45aa841486eb8c40adb68'), 'sepal_length': 5.1, 'sepal_width': 3.5, 'petal_length': 1.4, 'petal_width': 0.2, 'species': 'setosa'}
# {'_id': ObjectId('65d45aa841486eb8c40adb69'), 'sepal_length': 4.9, 'sepal_width': 3.0, 'petal_length': 1.4, 'petal_width': 0.2, 'species': 'setosa'}
# {'_id': ObjectId('65d45aa841486eb8c40adb6a'), 'sepal_length': 4.7, 'sepal_width': 3.2, 'petal_length': 1.3, 'petal_width': 0.2, 'species': 'setosa'}
# {'_id': ObjectId('65d45aa841486eb8c40adb6b'), 'sepal_length': 4.6, 'sepal_width': 3.1, 'petal_length': 1.5, 'petal_width': 0.2, 'species': 'setosa'}
# {'_id': ObjectId('65d45aa841486eb8c40adb6c'), 'sepal_length': 5.0, 'sepal_width': 3.6, 'petal_length': 1.4, 'petal_width': 0.2, 'species': 'setosa'}
# {'_id': ObjectId('65d45aa841486eb8c40adb6d'), 'sepal_length': 5.4, 'sepal_width': 3.9, 'petal_length': 1.7, 'petal_width': 0.4, 'species': 'setosa'}
# ...
