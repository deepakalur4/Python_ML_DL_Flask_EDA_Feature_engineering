# %% [markdown]
# **Import Necessary Libraries**

# %%
# !pip install flask --quiet
# !pip install flask-ngrok --quiet
print("Completed!")
# Out:
# Completed!

# %% [markdown]
# **Setup and Installation of Ngrok**

# %%
# install ngrok linux version using the following command or you can get the
# latest version from its official website- https://dashboard.ngrok.com/get-started/setup

# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.tgz
# Out:
# --2024-02-06 17:25:23--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.tgz
# Resolving bin.equinox.io (bin.equinox.io)... 18.205.222.128, 52.202.168.65, 54.161.241.46, ...
# Connecting to bin.equinox.io (bin.equinox.io)|18.205.222.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13856790 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.tgz.2’
#
# ngrok-stable-linux- 100%[===================>]  13.21M  36.2MB/s    in 0.4s
#
# 2024-02-06 17:25:24 (36.2 MB/s) - ‘ngrok-stable-linux-amd64.tgz.2’ saved [13856790/13856790]

# %%
# extract the downloaded file using the following command

# !tar -xvf /content/ngrok-stable-linux-amd64.tgz
# Out:
# ngrok

# %% [markdown]
# **The next step is to get your AuthToken from ngrok using this link-** https://dashboard.ngrok.com/get-started/your-authtoken

# %%
# paste your AuthToken here and execute this command

# !./ngrok authtoken 2c0D5f0bcQ9M76y3wyMZYjzM6no_6iUkERjRsGtA817YcWtv3
# Out:
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %% [markdown]
# **Creating A Simple Hello World Application Using Python Flask Module**

# %%
# import Flask from flask module
from flask import Flask

# import run_with_ngrok from flask_ngrok to run the app using ngrok
from flask_ngrok import run_with_ngrok

app = Flask(__name__) #app name
run_with_ngrok(app)

@app.route("/")
def hello():
    return "Hi Deepu"

if __name__ == "__main__":
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
#  * Running on http://392d-104-198-129-188.ngrok-free.app
#  * Traffic stats available on http://127.0.0.1:4040
# INFO:werkzeug:127.0.0.1 - - [06/Feb/2024 17:27:15] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Feb/2024 17:27:16] "GET /favicon.ico HTTP/1.1" 404 -

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-3f786850e387> in <cell line: 1>()
# ----> 1 a
#
# NameError: name 'a' is not defined
