# %%
url = "https://www.slideshare.net/PrabaharanM/nem12493mprabaharan-4"

# get the url from requests get method
read = requests.get(url)

# full html content
html_content = read.content

# Parse the html content
soup = bs4.BeautifulSoup(html_content, "lxml")

# %%
import bs4,requests,lxml

# %%
list_of_pdf = set()

# accessed the first p tag in the html
l = soup.find("div",class_="slide-container SlideContainer_container__ObYN4 SlideContainer_transform0__pYIkT SlideContainer_vertical__uKNJO")

# # accessed all the anchors tag from given p tag
# p = l.find('a')

# # iterate through p for getting all the href links
# for link in l:

#     # original html links
#     print("links: ", link.get('href'))
#     print("\n")

#     # converting the extension from .html to .pdf
#     pdf_link = (link.get('href')[:-5]) + ".pdf"

#     # converted to .pdf
#     print("converted pdf links: ", pdf_link)
#     print("\n")

#     # added all the pdf links to set
#     list_of_pdf.add(pdf_link)
# Out:
# links:  None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-1a6de3f0a651> in <cell line: 10>()
#      15
#      16     # converting the extension from .html to .pdf
# ---> 17     pdf_link = (link.get('href')[:-5]) + ".pdf"
#      18
#      19     # converted to .pdf
#
# TypeError: 'NoneType' object is not subscriptable

# %%
l = soup.find("div",class_="SlideContainer_inner__Tgjfc SlideContainer_vertical__uKNJO")

# %%
a=l.find("div",class_="slide SlideContainer_verticalSlide__BKDno Slide_container__2bbRA Slide_vertical__Iosjh").find("div",class_="Slide_inner__z7XvM").find("picture",class_="SlideImage_picture__a3aKk")

# %%
a

# %%
a
# Out:
# []
