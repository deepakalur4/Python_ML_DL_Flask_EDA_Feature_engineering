# %%
# !pip install pyspark
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.0/317.0 MB 4.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyspark: filename=pyspark-3.5.1-py2.py3-none-any.whl size=317488493 sha256=25d8f049ea574d81abfd64180eb488601579b2af7178580a382a15b8502ef817
#   Stored in directory: /root/.cache/pip/wheels/80/1d/60/2c256ed38dddce2fdd93be545214a63e02fbd8d74fb0b7f3a6
# Successfully built pyspark
# ...

# %%
import pyspark

# %%
import pandas as pd

# %%
df=pd.read_excel("Financial Sample.xlsx")

# %%
df.to_csv("test.csv")

# %%
from pyspark.sql import SparkSession

# %%
sessipon=SparkSession.builder.appName("test app").getOrCreate()

# %%
sessipon
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://7722f5439645:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>test app</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
speak_df=sessipon.read.csv("test.csv",header=True,inferSchema=True)

# %%
speak_df.show(5)
# Out:
# +---+----------+-------+---------+-------------+----------+-------------------+----------+-----------+---------+-------+-------+-------+----------+------------+----------+------+
# |_c0|   Segment|Country|  Product|Discount Band|Units Sold|Manufacturing Price|Sale Price|Gross Sales|Discounts|  Sales|   COGS| Profit|      Date|Month Number|Month Name|  Year|
# +---+----------+-------+---------+-------------+----------+-------------------+----------+-----------+---------+-------+-------+-------+----------+------------+----------+------+
# |  0|Government| Canada|Carretera|         None|    1618.5|                  3|        20|    32370.0|      0.0|32370.0|16185.0|16185.0|2014-01-01|           1|   January|2014.0|
# |  1|Government|Germany|Carretera|         None|    1321.0|                  3|        20|    26420.0|      0.0|26420.0|13210.0|13210.0|2014-01-01|           1|   January|2014.0|
# ...

# %%
speak_df
# Out:
# DataFrame[_c0: int, Segment: string, Country: string, Product: string, Discount Band: string, Units Sold: double, Manufacturing Price: int, Sale Price: int, Gross Sales: double, Discounts: double,  Sales: double, COGS: double, Profit: double, Date: date, Month Number: int, Month Name: string, Year: double]

# %%
speak_df.describe().show()
# Out:
# +-------+------------------+----------------+--------------------+--------+-------------+------------------+-------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+----------+-------------------+
# |summary|               _c0|         Segment|             Country| Product|Discount Band|        Units Sold|Manufacturing Price|        Sale Price|       Gross Sales|         Discounts|             Sales|              COGS|            Profit|      Month Number|Month Name|               Year|
# +-------+------------------+----------------+--------------------+--------+-------------+------------------+-------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+----------+-------------------+
# ...

# %%
speak_df.columns
# Out:
# ['_c0',
#  'Segment',
#  'Country',
#  'Product',
#  'Discount Band',
#  'Units Sold',
#  'Manufacturing Price',
#  'Sale Price',
#  'Gross Sales',
#  'Discounts',
#  ' Sales',
#  'COGS',
#  'Profit',
#  'Date',
#  'Month Number',
#  'Month Name',
#  'Year']

# %%
speak_df.groupBy("Product").mean().select("Product","avg(Sale Price)").show()
# Out:
# +---------+------------------+
# |  Product|   avg(Sale Price)|
# +---------+------------------+
# |    Paseo|108.17821782178218|
# |     Velo|115.23853211009174|
# |  Montana|117.09677419354838|
# |      VTT|138.58715596330276|
# | Amarilla|128.68085106382978|
# |Carretera| 111.7741935483871|
# +---------+------------------+

# %%
speak_df.drop("Product").show()
# Out:
# +---+----------------+--------------------+-------------+----------+-------------------+----------+-----------+---------+--------+--------+--------+----------+------------+----------+------+
# |_c0|         Segment|             Country|Discount Band|Units Sold|Manufacturing Price|Sale Price|Gross Sales|Discounts|   Sales|    COGS|  Profit|      Date|Month Number|Month Name|  Year|
# +---+----------------+--------------------+-------------+----------+-------------------+----------+-----------+---------+--------+--------+--------+----------+------------+----------+------+
# |  0|      Government|              Canada|         None|    1618.5|                  3|        20|    32370.0|      0.0| 32370.0| 16185.0| 16185.0|2014-01-01|           1|   January|2014.0|
# |  1|      Government|             Germany|         None|    1321.0|                  3|        20|    26420.0|      0.0| 26420.0| 13210.0| 13210.0|2014-01-01|           1|   January|2014.0|
# ...

# %%
speak_df.withColumnRenamed("Country","deepau").show()
# Out:
# +---+----------------+--------------------+---------+-------------+----------+-------------------+----------+-----------+---------+--------+--------+--------+----------+------------+----------+------+
# |_c0|         Segment|              deepau|  Product|Discount Band|Units Sold|Manufacturing Price|Sale Price|Gross Sales|Discounts|   Sales|    COGS|  Profit|      Date|Month Number|Month Name|  Year|
# +---+----------------+--------------------+---------+-------------+----------+-------------------+----------+-----------+---------+--------+--------+--------+----------+------------+----------+------+
# |  0|      Government|              Canada|Carretera|         None|    1618.5|                  3|        20|    32370.0|      0.0| 32370.0| 16185.0| 16185.0|2014-01-01|           1|   January|2014.0|
# ...

# %%
speak_df.withColumn("Manufacturing Price",speak_df["Manufacturing Price"]*100).show()
# Out:
# +---+----------------+--------------------+---------+-------------+----------+-------------------+----------+-----------+---------+--------+--------+--------+----------+------------+----------+------+
# |_c0|         Segment|             Country|  Product|Discount Band|Units Sold|Manufacturing Price|Sale Price|Gross Sales|Discounts|   Sales|    COGS|  Profit|      Date|Month Number|Month Name|  Year|
# +---+----------------+--------------------+---------+-------------+----------+-------------------+----------+-----------+---------+--------+--------+--------+----------+------------+----------+------+
# |  0|      Government|              Canada|Carretera|         None|    1618.5|                300|        20|    32370.0|      0.0| 32370.0| 16185.0| 16185.0|2014-01-01|           1|   January|2014.0|
# ...

# %%
speak_df.filter((speak_df["Product"]=="Carretera") & (speak_df["Sale Price"]>100)).show()
# Out:
# +---+--------------+--------------------+---------+-------------+----------+-------------------+----------+-----------+---------+----------+--------+--------+----------+------------+----------+------+
# |_c0|       Segment|             Country|  Product|Discount Band|Units Sold|Manufacturing Price|Sale Price|Gross Sales|Discounts|     Sales|    COGS|  Profit|      Date|Month Number|Month Name|  Year|
# +---+--------------+--------------------+---------+-------------+----------+-------------------+----------+-----------+---------+----------+--------+--------+----------+------------+----------+------+
# |  5|    Government|             Germany|Carretera|         None|    1513.0|                  3|       350|   529550.0|      0.0|  529550.0|393380.0|136170.0|2014-12-01|          12|  December|2014.0|
# ...

# %%
df=speak_df.toPandas()

# %%
speak_df.
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    _c0     Segment  Country    Product Discount Band  Units Sold  \
# 0    0  Government   Canada  Carretera          None      1618.5
# 1    1  Government  Germany  Carretera          None      1321.0
# 2    2   Midmarket   France  Carretera          None      2178.0
# 3    3   Midmarket  Germany  Carretera          None       888.0
# 4    4   Midmarket   Mexico  Carretera          None      2470.0
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts    Sales     COGS  \
# 0                    3          20      32370.0        0.0  32370.0  16185.0
# 1                    3          20      26420.0        0.0  26420.0  13210.0
# 2                    3          15      32670.0        0.0  32670.0  21780.0
# 3                    3          15      13320.0        0.0  13320.0   8880.0
# 4                    3          15      37050.0        0.0  37050.0  24700.0
#
#     Profit        Date  Month Number Month Name    Year
# ...
