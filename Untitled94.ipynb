# %%
# !pip install pyspark

# %%
import pyspark,pandas as pd

# %%
df=pd.read_excel("Financial Sample.xlsx")

# %%
df.to_csv("test.csv")

# %%
from pyspark.sql import SparkSession

# %%
spark=SparkSession.builder.appName("testing purpose").getOrCreate()

# %%
spark_df=spark.read.option("header","True").csv("test.csv",inferSchema=True)

# %%
spark_df.printSchema()
# Out:
# root
#  |-- _c0: integer (nullable = true)
#  |-- Segment: string (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- Product: string (nullable = true)
#  |-- Discount Band: string (nullable = true)
#  |-- Units Sold: double (nullable = true)
#  |-- Manufacturing Price: integer (nullable = true)
#  |-- Sale Price: integer (nullable = true)
#  |-- Gross Sales: double (nullable = true)
#  |-- Discounts: double (nullable = true)
#  |--  Sales: double (nullable = true)
#  |-- COGS: double (nullable = true)
#  |-- Profit: double (nullable = true)
#  |-- Date: date (nullable = true)
#  |-- Month Number: integer (nullable = true)
#  |-- Month Name: string (nullable = true)
#  |-- Year: integer (nullable = true)

# %%
spark_df.show(5)
# Out:
# +---+----------+-------+---------+-------------+----------+-------------------+----------+-----------+---------+-------+-------+-------+----------+------------+----------+----+
# |_c0|   Segment|Country|  Product|Discount Band|Units Sold|Manufacturing Price|Sale Price|Gross Sales|Discounts|  Sales|   COGS| Profit|      Date|Month Number|Month Name|Year|
# +---+----------+-------+---------+-------------+----------+-------------------+----------+-----------+---------+-------+-------+-------+----------+------------+----------+----+
# |  0|Government| Canada|Carretera|         None|    1618.5|                  3|        20|    32370.0|      0.0|32370.0|16185.0|16185.0|2014-01-01|           1|   January|2014|
# |  1|Government|Germany|Carretera|         None|    1321.0|                  3|        20|    26420.0|      0.0|26420.0|13210.0|13210.0|2014-01-01|           1|   January|2014|
# ...

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://68266e6ae682:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>testing name</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
spark_df.columns
# Out:
# ['_c0',
#  'Segment',
#  'Country',
#  'Product',
#  'Discount Band',
#  'Units Sold',
#  'Manufacturing Price',
#  'Sale Price',
#  'Gross Sales',
#  'Discounts',
#  ' Sales',
#  'COGS',
#  'Profit',
#  'Date',
#  'Month Number',
#  'Month Name',
#  'Year']

# %%
spark_df.head(3)
# Out:
# [Row(_c0=0, Segment='Government', Country='Canada', Product='Carretera', Discount Band='None', Units Sold=1618.5, Manufacturing Price=3, Sale Price=20, Gross Sales=32370.0, Discounts=0.0,  Sales=32370.0, COGS=16185.0, Profit=16185.0, Date=datetime.date(2014, 1, 1), Month Number=1, Month Name='January', Year=2014),
#  Row(_c0=1, Segment='Government', Country='Germany', Product='Carretera', Discount Band='None', Units Sold=1321.0, Manufacturing Price=3, Sale Price=20, Gross Sales=26420.0, Discounts=0.0,  Sales=26420.0, COGS=13210.0, Profit=13210.0, Date=datetime.date(2014, 1, 1), Month Number=1, Month Name='January', Year=2014),
#  Row(_c0=2, Segment='Midmarket', Country='France', Product='Carretera', Discount Band='None', Units Sold=2178.0, Manufacturing Price=3, Sale Price=15, Gross Sales=32670.0, Discounts=0.0,  Sales=32670.0, COGS=21780.0, Profit=10890.0, Date=datetime.date(2014, 6, 1), Month Number=6, Month Name='June', Year=2014)]

# %%
spark_df.show()
# Out:
# +---+----------------+--------------------+---------+-------------+----------+-------------------+----------+-----------+---------+--------+--------+--------+----------+------------+----------+----+
# |_c0|         Segment|             Country|  Product|Discount Band|Units Sold|Manufacturing Price|Sale Price|Gross Sales|Discounts|   Sales|    COGS|  Profit|      Date|Month Number|Month Name|Year|
# +---+----------------+--------------------+---------+-------------+----------+-------------------+----------+-----------+---------+--------+--------+--------+----------+------------+----------+----+
# |  0|      Government|              Canada|Carretera|         None|    1618.5|                  3|        20|    32370.0|      0.0| 32370.0| 16185.0| 16185.0|2014-01-01|           1|   January|2014|
# ...

# %%
spark_df.select(["Country","Product"]).show()
# Out:
# +--------------------+---------+
# |             Country|  Product|
# +--------------------+---------+
# |              Canada|Carretera|
# |             Germany|Carretera|
# |              France|Carretera|
# |             Germany|Carretera|
# |              Mexico|Carretera|
# |             Germany|Carretera|
# |             Germany|  Montana|
# |              Canada|  Montana|
# |              France|  Montana|
# |             Germany|  Montana|
# |              Mexico|  Montana|
# |              Canada|  Montana|
# |              Mexico|  Montana|
# |             Germany|  Montana|
# |              Canada|  Montana|
# |United States of ...|  Montana|
# |              Canada|    Paseo|
# |              Mexico|    Paseo|
# |              Canada|    Paseo|
# |             Germany|    Paseo|
# +--------------------+---------+
# only showing top 20 rows

# %%
spark_df.dtypes
# Out:
# [('_c0', 'int'),
#  ('Segment', 'string'),
#  ('Country', 'string'),
#  ('Product', 'string'),
#  ('Discount Band', 'string'),
#  ('Units Sold', 'double'),
#  ('Manufacturing Price', 'int'),
#  ('Sale Price', 'int'),
#  ('Gross Sales', 'double'),
#  ('Discounts', 'double'),
#  (' Sales', 'double'),
#  ('COGS', 'double'),
#  ('Profit', 'double'),
#  ('Date', 'date'),
#  ('Month Number', 'int'),
#  ('Month Name', 'string'),
#  ('Year', 'int')]

# %%
spark_df.describe().show()
# Out:
# +-------+------------------+----------------+--------------------+--------+-------------+------------------+-------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+----------+------------------+
# |summary|               _c0|         Segment|             Country| Product|Discount Band|        Units Sold|Manufacturing Price|        Sale Price|       Gross Sales|         Discounts|             Sales|              COGS|            Profit|      Month Number|Month Name|              Year|
# +-------+------------------+----------------+--------------------+--------+-------------+------------------+-------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+----------+------------------+
# ...

# %%
spark_df.withColumn("Deepu",spark_df["Manufacturing Price"]*2).show()
# Out:
# +---+----------------+--------------------+---------+-------------+----------+-------------------+----------+-----------+---------+--------+--------+--------+----------+------------+----------+----+-----+
# |_c0|         Segment|             Country|  Product|Discount Band|Units Sold|Manufacturing Price|Sale Price|Gross Sales|Discounts|   Sales|    COGS|  Profit|      Date|Month Number|Month Name|Year|Deepu|
# +---+----------------+--------------------+---------+-------------+----------+-------------------+----------+-----------+---------+--------+--------+--------+----------+------------+----------+----+-----+
# |  0|      Government|              Canada|Carretera|         None|    1618.5|                  3|        20|    32370.0|      0.0| 32370.0| 16185.0| 16185.0|2014-01-01|           1|   January|2014|    6|
# ...

# %%
spark_df.withColumn("aa",spark_df["Year"]*10).show()
# Out:
# +---+----------------+--------------------+---------+-------------+----------+-------------------+----------+-----------+---------+--------+--------+--------+----------+------------+----------+----+-----+
# |_c0|         Segment|             Country|  Product|Discount Band|Units Sold|Manufacturing Price|Sale Price|Gross Sales|Discounts|   Sales|    COGS|  Profit|      Date|Month Number|Month Name|Year|   aa|
# +---+----------------+--------------------+---------+-------------+----------+-------------------+----------+-----------+---------+--------+--------+--------+----------+------------+----------+----+-----+
# |  0|      Government|              Canada|Carretera|         None|    1618.5|                  3|        20|    32370.0|      0.0| 32370.0| 16185.0| 16185.0|2014-01-01|           1|   January|2014|20140|
# ...
