# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/codebasics/deep-learning-keras-tf-tutorial/master/14_imbalanced/customer_churn.csv")

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# #Under_Sampling of majority clas

# %%
class_0,class_1=df["Churn"].value_counts()

# %%
# Out:
# 5174

# %%
df["Churn"]=df["Churn"].apply(lambda x:1 if x=="Yes" else 0)

# %%
df1=df[df["Churn"]==0].sample(1869,random_state=100)
df2=df[df["Churn"]==1].sample(1869,random_state=100)

# %%
df=pd.concat([df1,df2],axis=0)

# %%
df["Churn"].value_counts()
# Out:
# 0    1869
# 1    1869
# Name: Churn, dtype: int64

# %%
df=pd.read_csv("https://raw.githubusercontent.com/codebasics/deep-learning-keras-tf-tutorial/master/14_imbalanced/customer_churn.csv")

# %%
df["Churn"].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
df[df["Churn"]=="Yes"].sample(5000,replace=True).shape
# Out:
# (5000, 21)

# %% [markdown]
# #SMOTE

# %%
pip install imbalanced-learn

# %%
from imblearn.over_sampling import SMOTE

# %%
smote=SMOTE(sampling_strategy="minority")

# %%
df["Churn"].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
x=df.drop("Churn",axis="columns")
y=df["Churn"]

# %%
y.value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
aa,yy=smote.fit_resample(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-65ea490d80b3> in <cell line: 1>()
# ----> 1 aa,yy=smote.fit_resample(x,y)
#
# /usr/local/lib/python3.10/dist-packages/imblearn/base.py in fit_resample(self, X, y)
#     201         """
#     202         self._validate_params()
# --> 203         return super().fit_resample(X, y)
#     204
#     205     def _more_tags(self):
#
# /usr/local/lib/python3.10/dist-packages/imblearn/base.py in fit_resample(self, X, y)
#      80         check_classification_targets(y)
#      81         arrays_transformer = ArraysTransformer(X, y)
# ---> 82         X, y, binarize_y = self._check_X_y(X, y)
#      83
#      84         self.sampling_strategy_ = check_sampling_strategy(
#
# /usr/local/lib/python3.10/dist-packages/imblearn/base.py in _check_X_y(self, X, y, accept_sparse)
#     154             accept_sparse = ["csr", "csc"]
# ...
