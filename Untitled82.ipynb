# %%
pip install cassandra-driver
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.8/18.8 MB 53.0 MB/s eta 0:00:00
# ...

# %%
print (cassandra.__version__)
# Out:
# 3.29.0

# %%
import cassandra

# %%
from cassandra.cluster import Cluster
from cassandra.auth import PlainTextAuthProvider
import json

# This secure connect bundle is autogenerated when you download your SCB,
# if yours is different update the file name below
cloud_config= {
  'secure_connect_bundle': 'secure-connect-casandra-demp.zip'
}

# This token JSON file is autogenerated when you download your token,
# if yours is different update the file name below
with open("casandra_demp-token.json") as f:
    secrets = json.load(f)

CLIENT_ID = secrets["clientId"]
CLIENT_SECRET = secrets["secret"]

auth_provider = PlainTextAuthProvider(CLIENT_ID, CLIENT_SECRET)
cluster = Cluster(cloud=cloud_config, auth_provider=auth_provider)
session = cluster.connect()

row = session.execute("select release_version from system.local").one()
if row:
  print(row[0])
else:
  print("An error occurred.")
# Out:
# WARNING:cassandra.cluster:Downgrading core protocol version from 66 to 65 for 2d0e1508-b1a8-473e-89c2-c6d42c80d62c-asia-south1.db.astra.datastax.com:29042:6b9fd578-4cba-4189-a1f0-c0349f3fe8d0. To avoid this, it is best practice to explicitly set Cluster(protocol_version) to the version supported by your cluster. http://datastax.github.io/python-driver/api/cassandra/cluster.html#cassandra.cluster.Cluster.protocol_version
# WARNING:cassandra.cluster:Downgrading core protocol version from 65 to 5 for 2d0e1508-b1a8-473e-89c2-c6d42c80d62c-asia-south1.db.astra.datastax.com:29042:6b9fd578-4cba-4189-a1f0-c0349f3fe8d0. To avoid this, it is best practice to explicitly set Cluster(protocol_version) to the version supported by your cluster. http://datastax.github.io/python-driver/api/cassandra/cluster.html#cassandra.cluster.Cluster.protocol_version
# ...

# %%
session.execute("use keyspace_test")

# %%
query='''create table Deepak
        (
        id int,
        first_name varchar,
        last_name varchar,
        city varchar,
        primary key(id)
        )
      '''

# %%
session.execute(query)

# %%
session.execute("insert into Deepak(id,first_name,last_name,city) values(2222,'adsa','asdsad','sad')")

# %%
for i in session.execute("select * from Deepak"):
  print(i,i[0])
# Out:
# Row(id=1111, city='sad', first_name='adsa', last_name='asdsad') 1111
# Row(id=1243, city='sad', first_name='adsa', last_name='asdsad') 1243
# Row(id=2222, city='sad', first_name='adsa', last_name='asdsad') 2222
