# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant_Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   lon                   9551 non-null   float64
#  8   lat                   9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  cost_for_two          9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code          lon          lat   cost_for_two  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000    9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381    1199.210763
# std     8.791521e+06     56.750546    41.467058    11.007935   16121.183073
# min     5.300000e+01      1.000000  -157.948486   -41.330428       0.000000
# 25%     3.019625e+05      1.000000    77.081343    28.478713     250.000000
# 50%     6.004089e+06      1.000000    77.191964    28.570469     400.000000
# 75%     1.835229e+07      1.000000    77.282006    28.642758     700.000000
# max     1.850065e+07    216.000000   174.832089    55.976980  800000.000000
#
#        Price_Range       Rating         Votes
# count  9551.000000  9551.000000   9551.000000
# mean      1.804837     2.666370    156.909748
# std       0.905609     1.516378    430.169145
# min       1.000000     0.000000      0.000000
# 25%       1.000000     2.500000      5.000000
# ...

# %%
df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant_Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# lon                     float64
# lat                     float64
# Cuisines                 object
# cost_for_two              int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price_Range               int64
# Rating                  float64
# Rating color             object
# Review                   object
# Votes                     int64
# dtype: object

# %%
df.corr()
# Out:
# <ipython-input-8-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                Restaurant ID  Country Code       lon       lat  cost_for_two  \
# Restaurant ID       1.000000      0.148471 -0.226081 -0.052081     -0.001693
# Country Code        0.148471      1.000000 -0.698299  0.019792      0.043225
# lon                -0.226081     -0.698299  1.000000  0.043207      0.045891
# lat                -0.052081      0.019792  0.043207  1.000000     -0.111088
# cost_for_two       -0.001693      0.043225  0.045891 -0.111088      1.000000
# Price_Range        -0.134540      0.243327 -0.078939 -0.166688      0.075083
# Rating             -0.326212      0.282189 -0.116818  0.000516      0.051792
# Votes              -0.147023      0.154530 -0.085101 -0.022962      0.067783
#
# ...

# %%
sns.heatmap(df.isnull(),yticklabels=False,cmap="viridis")
# Out:
# <Axes: >

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant_Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# lon                     0
# lat                     0
# Cuisines                9
# cost_for_two            0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price_Range             0
# Rating                  0
# Rating color            0
# Review                  0
# Votes                   0
# dtype: int64

# %%
null_col=[col for col in df.columns if df[col].isnull().sum()>0]

# %%
null_col
# Out:
# ['Cuisines']

# %%
df.shape
# Out:
# (9551, 21)

# %%
df2={
    "Country Code":[1,14,30,37,94],
    "country":["india","Australia","brazil","Canada","indonasia"]

}

# %%
df2=pd.DataFrame(df2)

# %%
df2
# Out:
#    Country Code    country
# 0             1      india
# 1            14  Australia
# 2            30     brazil
# 3            37     Canada
# 4            94  indonasia

# %%
df=pd.merge(df,df2,on="Country Code",how="left")

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant_Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant_Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# lon                     float64
# lat                     float64
# Cuisines                 object
# cost_for_two              int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price_Range               int64
# Rating                  float64
# Rating color             object
# Review                   object
# Votes                     int64
# country                  object
# dtype: object

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant_Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'lon', 'lat', 'Cuisines',
#        'cost_for_two', 'Currency', 'Has Table booking', 'Has Online delivery',
#        'Is delivering now', 'Switch to order menu', 'Price_Range', 'Rating',
#        'Rating color', 'Review', 'Votes', 'country'],
#       dtype='object')

# %%
country_index=df["country"].value_counts().index

# %%
country_index
# Out:
# Index(['india', 'brazil', 'Australia', 'indonasia', 'Canada'], dtype='object')

# %%
country_values=df["country"].value_counts().values

# %%
##Pie Chart

# %%
plt.pie(country_values[:3],labels=country_index[:3],autopct="%1.2f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x7c39d1d21b40>,
# ...
#  [Text(-1.0994981653312474, 0.033223251394479604, 'india'),
#   Text(1.099170479968382, -0.042711309580452446, 'brazil'),
#   Text(1.0999590322211832, -0.009493547020915913, 'Australia')],
#  [Text(-0.5997262719988622, 0.018121773487897962, '99.04%'),
#   Text(0.5995475345282082, -0.023297077952974057, '0.69%'),
#   Text(0.5999776539388271, -0.005178298375045042, '0.27%')])

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant_Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'lon', 'lat', 'Cuisines',
#        'cost_for_two', 'Currency', 'Has Table booking', 'Has Online delivery',
#        'Is delivering now', 'Switch to order menu', 'Price_Range', 'Rating',
#        'Rating color', 'Review', 'Votes', 'country'],
#       dtype='object')

# %%
rating_df=df.groupby(["country","Rating color"])["Rating"].count().reset_index().rename(columns={0:"Votes"})

# %%
rating_df
# Out:
#       country Rating color  Rating
# 0   Australia   Dark Green       1
# 1   Australia        Green       5
# 2   Australia       Orange       4
# 3   Australia          Red       1
# 4   Australia       Yellow      13
# 5      Canada        Green       1
# 6      Canada       Orange       2
# 7      Canada       Yellow       1
# 8      brazil   Dark Green      16
# 9      brazil        Green      20
# 10     brazil       Orange       8
# 11     brazil        White       5
# 12     brazil       Yellow      11
# 13      india   Dark Green     116
# 14      india        Green     692
# 15      india       Orange    3678
# 16      india          Red     180
# 17      india        White    2139
# 18      india       Yellow    1847
# 19  indonasia   Dark Green       7
# 20  indonasia        Green      10
# 21  indonasia       Orange       1
# 22  indonasia       Yellow       3

# %%
import matplotlib
matplotlib.rcParams["figure.figsize"]=(12,6)
sns.barplot(x=rating_df["country"],y=rating_df["Rating"])
# Out:
# <Axes: xlabel='country', ylabel='Rating'>

# %%
sns.countplot(x=df["Rating color"],palette=["Blue","Orange","green","red","green","White"])
# Out:
# <Axes: xlabel='Rating color', ylabel='count'>

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant_Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'lon', 'lat', 'Cuisines',
#        'cost_for_two', 'Currency', 'Has Table booking', 'Has Online delivery',
#        'Is delivering now', 'Switch to order menu', 'Price_Range', 'Rating',
#        'Rating color', 'Review', 'Votes', 'country'],
#       dtype='object')

# %%
aa=df[df["Rating"]==0].groupby("country").count()[["Rating"]].reset_index()

# %%
aa
# Out:
#   country  Rating
# 0  brazil       5
# 1   india    2139

# %%
aa.sort_values(by=["Rating"],ascending=False)
# Out:
#   country  Rating
# 1   india    2139
# 0  brazil       5

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant_Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'lon', 'lat', 'Cuisines',
#        'cost_for_two', 'Currency', 'Has Table booking', 'Has Online delivery',
#        'Is delivering now', 'Switch to order menu', 'Price_Range', 'Rating',
#        'Rating color', 'Review', 'Votes', 'country'],
#       dtype='object')

# %%
df[["Currency","country"]].groupby(["Currency","country"]).size().reset_index()
# Out:
#                  Currency    country     0
# 0      Brazilian Real(R$)     brazil    60
# 1               Dollar($)  Australia    24
# 2               Dollar($)     Canada     4
# 3      Indian Rupees(Rs.)      india  8652
# 4  Indonesian Rupiah(IDR)  indonasia    21

# %%
aa=df[["Currency","country"]].groupby(["Currency","country"]).size().reset_index()

# %%
df.groupby(["Currency","country"]).size().reset_index()
# Out:
#                  Currency    country     0
# 0      Brazilian Real(R$)     brazil    60
# 1               Dollar($)  Australia    24
# 2               Dollar($)     Canada     4
# 3      Indian Rupees(Rs.)      india  8652
# 4  Indonesian Rupiah(IDR)  indonasia    21

# %%
aa[0].sum()
# Out:
# 8761

# %%
df.shape
# Out:
# (9551, 22)

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant_Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'lon', 'lat', 'Cuisines',
#        'cost_for_two', 'Currency', 'Has Table booking', 'Has Online delivery',
#        'Is delivering now', 'Switch to order menu', 'Price_Range', 'Rating',
#        'Rating color', 'Review', 'Votes', 'country'],
#       dtype='object')

# %%
df[df["Has Online delivery"]=="Yes"][["Restaurant_Name","Has Online delivery"]].value_counts()
# Out:
# Restaurant_Name     Has Online delivery
# Subway              Yes                    47
# McDonald's          Yes                    30
# Pizza Hut Delivery  Yes                    18
# KFC                 Yes                    15
# Chaayos             Yes                    15
#                                            ..
# Great Plates By AJ  Yes                     1
# Gravity             Yes                     1
# Gravies             Yes                     1
# Grandma's Kitchen   Yes                     1
# iKitchen            Yes                     1
# Length: 1728, dtype: int64

# %%
df.groupby(["Restaurant_Name","Has Online delivery"]).size().reset_index()
# Out:
# <ipython-input-119-396533dad5c6>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df.groupby(["Restaurant_Name","Has Online delivery"]).size().reset_index()[df["Has Online delivery"]=="Yes"]
#                    Restaurant_Name Has Online delivery  0
# 565           Backyard Underground                  No  1
# 566   Bade Bhai Ka Brothers' Dhaba                  No  1
# 571             Bailey's Bar-B-Que                  No  1
# 572                Bait El Khetyar                 Yes  1
# 573            Bajaj Vaishno Dhaba                  No  1
# ...                            ...                 ... ..
# 7640                 Zuka Choco-la                  No  1
# 7641        Zune - Piccadily Hotel                  No  1
# 7642                       Zunzi's                  No  1
# 7653                sketch Gallery                  No  1
# 7655                        tashas                  No  1
#
# [1985 rows x 3 columns]

# %%
df["country"].value_counts().values
# Out:
# array([8652,   60,   24,   21,    4])

# %%
df["country"].value_counts().index
# Out:
# Index(['india', 'brazil', 'Australia', 'indonasia', 'Canada'], dtype='object')

# %%
plt.pie(df["City"].value_counts()[:5].values,labels=df["City"].value_counts()[:5].index,autopct="%1.2f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x7c39c96125f0>,
# ...
#  [Text(-0.6145352824185932, 0.9123301960708633, 'New Delhi'),
#   Text(0.0623675251198054, -1.0982305276263407, 'Gurgaon'),
#   Text(0.8789045225625368, -0.6614581167535246, 'Noida'),
#   Text(1.0922218418223437, -0.13058119407559224, 'Faridabad'),
#   Text(1.099946280005612, -0.010871113182029924, 'Ghaziabad')],
#  [Text(-0.3352010631374145, 0.497634652402289, '68.87%'),
#   Text(0.0340186500653484, -0.5990348332507311, '14.07%'),
#   Text(0.47940246685229276, -0.36079533641101336, '13.59%'),
#   Text(0.5957573682667329, -0.07122610585941394, '3.16%'),
#   Text(0.5999706981848791, -0.005929698099289049, '0.31%')])

# %%
df["country"].value_counts()
# Out:
# india        8652
# brazil         60
# Australia      24
# indonasia      21
# Canada          4
# Name: country, dtype: int64

# %%
df=pd.read_csv("test.csv")

# %%
df.head()
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000004  P00128942      M  46-50           7             B
# 1  1000009  P00113442      M  26-35          17             C
# 2  1000010  P00288442      F  36-45           1             B
# 3  1000010  P00145342      F  36-45           1             B
# 4  1000011  P00053842      F  26-35           1             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
# 2                         4+               1                   5
# 3                         4+               1                   4
# 4                          1               0                   4
#
#    Product_Category_2  Product_Category_3
# 0                11.0                 NaN
# 1                 5.0                 NaN
# 2                14.0                 NaN
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_train=pd.read_csv("train.csv")

# %%
df_train.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
df_train.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
df_train.shape
# Out:
# (550068, 12)

# %%
df_test=pd.read_csv("test.csv")

# %%
df_test.head()
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000004  P00128942      M  46-50           7             B
# 1  1000009  P00113442      M  26-35          17             C
# 2  1000010  P00288442      F  36-45           1             B
# 3  1000010  P00145342      F  36-45           1             B
# 4  1000011  P00053842      F  26-35           1             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
# 2                         4+               1                   5
# 3                         4+               1                   4
# 4                          1               0                   4
#
#    Product_Category_2  Product_Category_3
# 0                11.0                 NaN
# 1                 5.0                 NaN
# 2                14.0                 NaN
# ...

# %%
df=df_train.append(df_test)
# Out:
# <ipython-input-281-66cce11fd376>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df_train.append(df_test)

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 783667 entries, 0 to 233598
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     783667 non-null  int64
#  1   Product_ID                  783667 non-null  object
#  2   Gender                      783667 non-null  object
#  3   Age                         783667 non-null  object
#  4   Occupation                  783667 non-null  int64
#  5   City_Category               783667 non-null  object
#  6   Stay_In_Current_City_Years  783667 non-null  object
#  7   Marital_Status              783667 non-null  int64
#  8   Product_Category_1          783667 non-null  int64
#  9   Product_Category_2          537685 non-null  float64
#  10  Product_Category_3          237858 non-null  float64
#  11  Purchase                    550068 non-null  float64
# dtypes: float64(3), int64(4), object(5)
# ...

# %%
df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  7.836670e+05  783667.000000   783667.000000       783667.000000
# mean   1.003029e+06       8.079300        0.409777            5.366196
# std    1.727267e+03       6.522206        0.491793            3.878160
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001519e+06       2.000000        0.000000            1.000000
# 50%    1.003075e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       537685.000000       237858.000000  550068.000000
# mean             9.844506           12.668605    9263.968713
# std              5.089093            4.125510    5023.065394
# min              2.000000            3.000000      12.000000
# ...

# %%
df.drop(["User_ID"],axis=1,inplace=True)

# %%
df.head()
# Out:
#   Product_ID Gender   Age  Occupation City_Category  \
# 0  P00069042      F  0-17          10             A
# 1  P00248942      F  0-17          10             A
# 2  P00087842      F  0-17          10             A
# 3  P00085442      F  0-17          10             A
# 4  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# ...

# %%
df.shape
# Out:
# (783667, 11)

# %%
cat_feat=[col for col in df.columns if df[col].dtype=='O']

# %%
num_feat=[col for col in df.columns if df[col].dtype!='O']

# %%
cat_feat
# Out:
# ['Product_ID', 'Gender', 'Age', 'City_Category', 'Stay_In_Current_City_Years']

# %%
num_feat
# Out:
# ['Occupation',
#  'Marital_Status',
#  'Product_Category_1',
#  'Product_Category_2',
#  'Product_Category_3',
#  'Purchase']

# %%
df["Gender"]=df["Gender"].map({"F":0,"M":1})

# %%
df.head()
# Out:
#   Product_ID  Gender   Age  Occupation City_Category  \
# 0  P00069042       0  0-17          10             A
# 1  P00248942       0  0-17          10             A
# 2  P00087842       0  0-17          10             A
# 3  P00085442       0  0-17          10             A
# 4  P00285442       1   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# ...

# %%
df["Age"].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df["Age"]=df["Age"].map({'0-17':1,'18-25':2,'26-35':3,"36-45":4,"46-50":5,"51-55":6,"55+":7})

# %%
df.head()
# Out:
#   Product_ID  Gender  Age  Occupation City_Category  \
# 0  P00069042       0    1          10             A
# 1  P00248942       0    1          10             A
# 2  P00087842       0    1          10             A
# 3  P00085442       0    1          10             A
# 4  P00285442       1    7          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# ...

# %%
df_city=pd.get_dummies(df["City_Category"],drop_first=True)

# %%
df=pd.concat([df,df_city],axis=1)

# %%
df
# Out:
#        Product_ID  Gender  Age  Occupation City_Category  \
# 0       P00069042       0    1          10             A
# 1       P00248942       0    1          10             A
# 2       P00087842       0    1          10             A
# 3       P00085442       0    1          10             A
# 4       P00285442       1    7          16             C
# ...           ...     ...  ...         ...           ...
# 233594  P00118942       0    3          15             B
# 233595  P00254642       0    3          15             B
# 233596  P00031842       0    3          15             B
# 233597  P00124742       0    5           1             C
# 233598  P00316642       0    5           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# ...

# %%
df.head()
# Out:
#   Product_ID  Gender  Age  Occupation City_Category  \
# 0  P00069042       0    1          10             A
# 1  P00248942       0    1          10             A
# 2  P00087842       0    1          10             A
# 3  P00085442       0    1          10             A
# 4  P00285442       1    7          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase  B  C
# 0                 NaN                 NaN    8370.0  0  0
# 1                 6.0                14.0   15200.0  0  0
# 2                 NaN                 NaN    1422.0  0  0
# ...

# %%
df.isnull().sum()
# Out:
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            245982
# Product_Category_3            545809
# Purchase                      233599
# B                                  0
# C                                  0
# dtype: int64

# %%
sns.heatmap(df.isnull(),yticklabels=False,cmap="viridis")
# Out:
# <Axes: >

# %%
df["Product_Category_2"].unique()
# Out:
# array([nan,  6., 14.,  2.,  8., 15., 16., 11.,  5.,  3.,  4., 12.,  9.,
#        10., 17., 13.,  7., 18.])

# %%
df["Product_Category_2"].value_counts()
# Out:
# 8.0     91317
# 14.0    78834
# 2.0     70498
# 16.0    61687
# 15.0    54114
# 5.0     37165
# 4.0     36705
# 6.0     23575
# 11.0    20230
# 17.0    19104
# 13.0    15054
# 9.0      8177
# 12.0     7801
# 10.0     4420
# 3.0      4123
# 18.0     4027
# 7.0       854
# Name: Product_Category_2, dtype: int64

# %%
df["Product_Category_2"].mode()
# Out:
# 0    8.0
# Name: Product_Category_2, dtype: float64

# %%
df["Product_Category_2"]=df["Product_Category_2"].fillna(df["Product_Category_2"].mode()[0])

# %%
df.head()
# Out:
#   Product_ID  Gender  Age  Occupation City_Category  \
# 0  P00069042       0    1          10             A
# 1  P00248942       0    1          10             A
# 2  P00087842       0    1          10             A
# 3  P00085442       0    1          10             A
# 4  P00285442       1    7          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase  B  C
# 0                 8.0                 NaN    8370.0  0  0
# 1                 6.0                14.0   15200.0  0  0
# 2                 8.0                 NaN    1422.0  0  0
# ...

# %%
df["Product_Category_2"].isnull().sum()
# Out:
# 0

# %%
df["Product_Category_3"].unique()
# Out:
# array([nan, 14., 17.,  5.,  4., 16., 15.,  8.,  9., 13.,  6., 12.,  3.,
#        18., 11., 10.])

# %%
df["Product_Category_3"].value_counts()
# Out:
# 16.0    46469
# 15.0    39968
# 14.0    26283
# 17.0    23818
# 5.0     23799
# 8.0     17861
# 9.0     16532
# 12.0    13115
# 13.0     7849
# 6.0      6888
# 18.0     6621
# 4.0      2691
# 11.0     2585
# 10.0     2501
# 3.0       878
# Name: Product_Category_3, dtype: int64

# %%
df["Product_Category_3"].mode()[0]
# Out:
# 16.0

# %%
df["Product_Category_3"]=df["Product_Category_3"].fillna(df["Product_Category_3"].mode()[0])

# %%
df.head()
# Out:
#   Product_ID  Gender  Age  Occupation City_Category  \
# 0  P00069042       0    1          10             A
# 1  P00248942       0    1          10             A
# 2  P00087842       0    1          10             A
# 3  P00085442       0    1          10             A
# 4  P00285442       1    7          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase  B  C
# 0                 8.0                16.0    8370.0  0  0
# 1                 6.0                14.0   15200.0  0  0
# 2                 8.0                16.0    1422.0  0  0
# ...

# %%
df["Stay_In_Current_City_Years"].unique()
# Out:
# array(['2', '4', '3', '1', '0'], dtype=object)

# %%
df["Stay_In_Current_City_Years"]=df["Stay_In_Current_City_Years"].str.replace("+","")
# Out:
# <ipython-input-328-d114f8657c51>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Stay_In_Current_City_Years"]=df["Stay_In_Current_City_Years"].str.replace("+","")

# %%
df.head()
# Out:
#   Product_ID  Gender  Age  Occupation City_Category  \
# 0  P00069042       0    1          10             A
# 1  P00248942       0    1          10             A
# 2  P00087842       0    1          10             A
# 3  P00085442       0    1          10             A
# 4  P00285442       1    7          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                          4               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase  B  C
# 0                 8.0                16.0    8370.0  0  0
# 1                 6.0                14.0   15200.0  0  0
# 2                 8.0                16.0    1422.0  0  0
# ...

# %%
df.drop("City_Category",axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 783667 entries, 0 to 233598
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Product_ID                  783667 non-null  object
#  1   Gender                      783667 non-null  int64
#  2   Age                         783667 non-null  int64
#  3   Occupation                  783667 non-null  int64
#  4   Stay_In_Current_City_Years  783667 non-null  object
#  5   Marital_Status              783667 non-null  int64
#  6   Product_Category_1          783667 non-null  int64
#  7   Product_Category_2          783667 non-null  float64
#  8   Product_Category_3          783667 non-null  float64
#  9   Purchase                    550068 non-null  float64
#  10  B                           783667 non-null  uint8
#  11  C                           783667 non-null  uint8
# dtypes: float64(3), int64(5), object(2), uint8(2)
# ...

# %%
df["Stay_In_Current_City_Years"]=df["Stay_In_Current_City_Years"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 783667 entries, 0 to 233598
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Product_ID                  783667 non-null  object
#  1   Gender                      783667 non-null  int64
#  2   Age                         783667 non-null  int64
#  3   Occupation                  783667 non-null  int64
#  4   Stay_In_Current_City_Years  783667 non-null  int64
#  5   Marital_Status              783667 non-null  int64
#  6   Product_Category_1          783667 non-null  int64
#  7   Product_Category_2          783667 non-null  float64
#  8   Product_Category_3          783667 non-null  float64
#  9   Purchase                    550068 non-null  float64
#  10  B                           783667 non-null  uint8
#  11  C                           783667 non-null  uint8
# dtypes: float64(3), int64(6), object(1), uint8(2)
# ...

# %%
df["B"]=df["B"].astype(int)
df["C"]=df["C"].astype(int)

# %%
df.head()
# Out:
#   Product_ID  Gender  Age  Occupation  Stay_In_Current_City_Years  \
# 0  P00069042       0    1          10                           2
# 1  P00248942       0    1          10                           2
# 2  P00087842       0    1          10                           2
# 3  P00085442       0    1          10                           2
# 4  P00285442       1    7          16                           4
#
#    Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3  \
# 0               0                   3                 8.0                16.0
# 1               0                   1                 6.0                14.0
# 2               0                  12                 8.0                16.0
# 3               0                  12                14.0                16.0
# 4               0                   8                 8.0                16.0
#
#    Purchase  B  C
# 0    8370.0  0  0
# 1   15200.0  0  0
# 2    1422.0  0  0
# 3    1057.0  0  0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 783667 entries, 0 to 233598
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Product_ID                  783667 non-null  object
#  1   Gender                      783667 non-null  int64
#  2   Age                         783667 non-null  int64
#  3   Occupation                  783667 non-null  int64
#  4   Stay_In_Current_City_Years  783667 non-null  int64
#  5   Marital_Status              783667 non-null  int64
#  6   Product_Category_1          783667 non-null  int64
#  7   Product_Category_2          783667 non-null  float64
#  8   Product_Category_3          783667 non-null  float64
#  9   Purchase                    550068 non-null  float64
#  10  B                           783667 non-null  int64
#  11  C                           783667 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# ...

# %%
sns.barplot(x=df["Age"],y=df["Purchase"],hue=df["Gender"])
# Out:
# <Axes: xlabel='Age', ylabel='Purchase'>

# %%
sns.barplot(x=df["Occupation"],y=df["Purchase"],hue=df["Gender"])
# Out:
# <Axes: xlabel='Occupation', ylabel='Purchase'>

# %%
sns.barplot(x=df["Product_Category_1"],y=df["Purchase"],hue=df["Gender"])
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='Purchase'>

# %%
sns.barplot(x=df["Product_Category_2"],y=df["Purchase"],hue=df["Gender"])
# Out:
# <Axes: xlabel='Product_Category_2', ylabel='Purchase'>

# %%
sns.barplot(x=df["Product_Category_3"],y=df["Purchase"],hue=df["Gender"])
# Out:
# <Axes: xlabel='Product_Category_3', ylabel='Purchase'>

# %%
df.head()
# Out:
#   Product_ID  Gender  Age  Occupation  Stay_In_Current_City_Years  \
# 0  P00069042       0    1          10                           2
# 1  P00248942       0    1          10                           2
# 2  P00087842       0    1          10                           2
# 3  P00085442       0    1          10                           2
# 4  P00285442       1    7          16                           4
#
#    Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3  \
# 0               0                   3                 8.0                16.0
# 1               0                   1                 6.0                14.0
# 2               0                  12                 8.0                16.0
# 3               0                  12                14.0                16.0
# 4               0                   8                 8.0                16.0
#
#    Purchase  B  C
# 0    8370.0  0  0
# 1   15200.0  0  0
# 2    1422.0  0  0
# 3    1057.0  0  0
# ...

# %%
df.drop("Product_ID",axis=1,inplace=True)

# %%
df.head()
# Out:
#    Gender  Age  Occupation  Stay_In_Current_City_Years  Marital_Status  \
# 0       0    1          10                           2               0
# 1       0    1          10                           2               0
# 2       0    1          10                           2               0
# 3       0    1          10                           2               0
# 4       1    7          16                           4               0
#
#    Product_Category_1  Product_Category_2  Product_Category_3  Purchase  B  C
# 0                   3                 8.0                16.0    8370.0  0  0
# 1                   1                 6.0                14.0   15200.0  0  0
# 2                  12                 8.0                16.0    1422.0  0  0
# 3                  12                14.0                16.0    1057.0  0  0
# 4                   8                 8.0                16.0    7969.0  0  1

# %%
df_test=df[df["Purchase"].isnull()]

# %%
df_train=df[~df["Purchase"].isnull()]

# %%
x=df_train.drop("Purchase",axis=1)
y=df_train["Purchase"]

# %%
x.shape
# Out:
# (550068, 10)

# %%
y.shape
# Out:
# (550068,)

# %%
x.head()
# Out:
#    Gender  Age  Occupation  Stay_In_Current_City_Years  Marital_Status  \
# 0       0    1          10                           2               0
# 1       0    1          10                           2               0
# 2       0    1          10                           2               0
# 3       0    1          10                           2               0
# 4       1    7          16                           4               0
#
#    Product_Category_1  Product_Category_2  Product_Category_3  B  C
# 0                   3                 8.0                16.0  0  0
# 1                   1                 6.0                14.0  0  0
# 2                  12                 8.0                16.0  0  0
# 3                  12                14.0                16.0  0  0
# 4                   8                 8.0                16.0  0  1

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
x_train=sc.fit_transform(X_train)
x_test=sc.fit_transform(X_test)
