# %%
# !pip install beautifulsoup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from bs4 import BeautifulSoup as bs
import requests

# %%
amazon_url="https://www.amazon.in/Skillmatics-Floor-Puzzle-Game-Construction/dp/B0BN3LMJRF/ref=sr_1_1_sspa?keywords=games&qid=1685470180&sr=8-1-spons&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&psc=1"

# %%
link=requests.get(amazon_url)
links=link.content

# %%
links=bs(links,"html.parser")

# %%
links.find("span",attrs={"id":"productTitle"})

# %%
links.find("span",attrs={"class":"a-price-whole"}).text.strip()

# %%
links.find("span",attrs={"class":"a-truncate a-size-base"}).text

# %%
amazon_iphone_url="https://www.amazon.in/s?k=iphone+14&sprefix=iphon%2Caps%2C387&ref=nb_sb_ss_ts-doa-p_1_5"

# %%
link=requests.get(amazon_iphone_url)

# %%
link

# %%
links=link.content

# %%
links=bs(links,"html.parser")

# %%
links.findAll("span",attrs={"class":"a-size-medium a-color-base a-text-normal"})[0].text
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-175-479bd4a7ab82> in <cell line: 1>()
# ----> 1 links.findAll("span",attrs={"class":"a-size-medium a-color-base a-text-normal"})[0].text
#
# IndexError: list index out of range

# %%
links.findAll("a",attrs={"class":"a-link-normal s-no-outline"})[0].get("href")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-176-5f3e70691abd> in <cell line: 1>()
# ----> 1 links.findAll("a",attrs={"class":"a-link-normal s-no-outline"})[0].get("href")
#
# IndexError: list index out of range

# %%
"https://www.amazon.in/"+links.findAll("a",attrs={"class":"a-link-normal s-no-outline"})[0].get("href")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-177-3d229c51fd45> in <cell line: 1>()
# ----> 1 "https://www.amazon.in/"+links.findAll("a",attrs={"class":"a-link-normal s-no-outline"})[0].get("href")
#
# IndexError: list index out of range

# %%
all_links=links.findAll("a",attrs={"class":"a-link-normal s-no-outline"})

# %%
href_link=[]
for links in all_links:
  href_link.append(links.get("href"))

# %%
href_link
# Out:
# ['/Apple-iPhone-14-128GB-Starlight/dp/B0BDK8LKPJ',
#  '/Apple-iPhone-14-128GB-Purple/dp/B0BDJ213TX',
#  '/Apple-iPhone-14-128-GB/dp/B0BXQ2V3NJ',
#  '/Apple-iPhone-14-256GB-Starlight/dp/B0BDJS3MRM',
#  '/Apple-iPhone-Plus-128GB-Purple/dp/B0BDJMSBXY',
#  '/Apple-iPhone-Plus-128GB-Blue/dp/B0BDK62STN',
#  '/Apple-iPhone-14-512GB-Blue/dp/B0BDJH3V3Q',
#  '/Apple-iPhone-512GB-Product-RED/dp/B0BDHY3LFJ',
#  '/Apple-iPhone-Plus-128GB-Midnight/dp/B0BDJKL7KM',
#  '/Apple-iPhone-14-512GB-Midnight/dp/B0BDJGX2XZ',
#  '/Apple-iPhone-Plus-128GB-Starlight/dp/B0BDJFTGK6',
#  '/Apple-iPhone-14-512GB-Starlight/dp/B0BDJBXLSJ',
#  '/Apple-iPhone-Plus-256GB-Blue/dp/B0BDJQHJZZ',
#  '/Apple-iPhone-Plus-256GB-Midnight/dp/B0BDJS1D9Y',
#  '/Apple-iPhone-256GB-Deep-Purple/dp/B0BDK2FB2T',
#  '/Apple-iPhone-Pro-128GB-Silver/dp/B0BDJDZ7RH']

# %%
url="https://www.amazon.in/s?k=iphone+14&crid=38D9WVN3GAW0G&sprefix=ip%2Caps%2C524&ref=nb_sb_ss_ts-doa-p_1_2"

# %%
link=requests.get(url)

# %%
link
# Out:
# <Response [200]>

# %%
content=link.content

# %%
links=bs(content,"html.parser")

# %%
links.findAll("a",attrs={"class":"a-link-normal s-no-outline"})
# Out:
# [<a class="a-link-normal s-no-outline" href="/Apple-iPhone-14-128GB-Starlight/dp/B0BDK8LKPJ" target="_blank"><div class="a-section aok-relative s-image-fixed-height"><img alt="Apple iPhone 14 (128 GB) - Starlight" class="s-image" data-image-index="1" data-image-latency="s-product-image" data-image-load="" data-image-source-density="1" src="https://m.media-amazon.com/images/I/618Bb+QzCmL._AC_UY218_.jpg" srcset="https://m.media-amazon.com/images/I/618Bb+QzCmL._AC_UY218_.jpg 1x, https://m.media-amazon.com/images/I/618Bb+QzCmL._AC_UY327_QL65_.jpg 1.5x, https://m.media-amazon.com/images/I/618Bb+QzCmL._AC_UY436_QL65_.jpg 2x, https://m.media-amazon.com/images/I/618Bb+QzCmL._AC_UY545_QL65_.jpg 2.5x, https://m.media-amazon.com/images/I/618Bb+QzCmL._AC_UY654_QL65_.jpg 3x"/></div></a>,
# ...

# %%
all_links=links.findAll("a",attrs={"class":"a-link-normal s-no-outline"})

# %%
href_link=[]
for link in all_links:
  href_link.append(link.get("href"))

# %%
href_link
# Out:
# ['/Apple-iPhone-14-128GB-Starlight/dp/B0BDK8LKPJ',
#  '/Apple-iPhone-14-128GB-Purple/dp/B0BDJ213TX',
#  '/Apple-iPhone-14-128-GB/dp/B0BXQ2V3NJ',
#  '/Apple-iPhone-14-256GB-Starlight/dp/B0BDJS3MRM',
#  '/Apple-iPhone-14-256-GB/dp/B0BXQ1ZL9N',
#  '/Apple-iPhone-Plus-128GB-Blue/dp/B0BDK62STN',
#  '/Apple-iPhone-Plus-128GB-Purple/dp/B0BDJMSBXY',
#  '/Apple-iPhone-14-512GB-Blue/dp/B0BDJH3V3Q',
#  '/Apple-iPhone-512GB-Product-RED/dp/B0BDHY3LFJ',
#  '/Apple-iPhone-Plus-128GB-Midnight/dp/B0BDJKL7KM',
#  '/Apple-iPhone-14-512GB-Midnight/dp/B0BDJGX2XZ',
#  '/Apple-iPhone-Plus-128GB-Starlight/dp/B0BDJFTGK6',
#  '/Apple-iPhone-14-512GB-Starlight/dp/B0BDJBXLSJ',
#  '/Apple-iPhone-Plus-256GB-Blue/dp/B0BDJQHJZZ',
#  '/Apple-iPhone-Plus-256GB-Midnight/dp/B0BDJS1D9Y',
#  '/Apple-iPhone-Pro-128GB-Silver/dp/B0BDJDZ7RH']

# %%
for everylink in href_link:
  print("https://www.amazon.in"+everylink)
# Out:
# https://www.amazon.in/Apple-iPhone-14-128GB-Starlight/dp/B0BDK8LKPJ
# https://www.amazon.in/Apple-iPhone-14-128GB-Purple/dp/B0BDJ213TX
# https://www.amazon.in/Apple-iPhone-14-128-GB/dp/B0BXQ2V3NJ
# https://www.amazon.in/Apple-iPhone-14-256GB-Starlight/dp/B0BDJS3MRM
# https://www.amazon.in/Apple-iPhone-14-256-GB/dp/B0BXQ1ZL9N
# https://www.amazon.in/Apple-iPhone-Plus-128GB-Blue/dp/B0BDK62STN
# https://www.amazon.in/Apple-iPhone-Plus-128GB-Purple/dp/B0BDJMSBXY
# https://www.amazon.in/Apple-iPhone-14-512GB-Blue/dp/B0BDJH3V3Q
# https://www.amazon.in/Apple-iPhone-512GB-Product-RED/dp/B0BDHY3LFJ
# https://www.amazon.in/Apple-iPhone-Plus-128GB-Midnight/dp/B0BDJKL7KM
# https://www.amazon.in/Apple-iPhone-14-512GB-Midnight/dp/B0BDJGX2XZ
# https://www.amazon.in/Apple-iPhone-Plus-128GB-Starlight/dp/B0BDJFTGK6
# https://www.amazon.in/Apple-iPhone-14-512GB-Starlight/dp/B0BDJBXLSJ
# https://www.amazon.in/Apple-iPhone-Plus-256GB-Blue/dp/B0BDJQHJZZ
# ...

# %%
for everylink in href_link:
  # every_sap_link=+everylink
  req=requests.get("https://www.amazon.in"+everylink)
  print(req)
# Out:
# <Response [503]>
# <Response [503]>
# <Response [503]>
# <Response [200]>
# <Response [503]>
# <Response [200]>
# <Response [503]>
# <Response [200]>
# <Response [200]>
# <Response [503]>
# <Response [200]>
# <Response [503]>
# <Response [503]>
# <Response [503]>
# <Response [503]>
# <Response [200]>

# %%
requests.get("https://www.amazon.in/Apple-iPhone-Plus-256GB-Midnight/dp/B0BDJS1D9Y")
# Out:
# <Response [503]>

# %%
https://www.amazon.in/Apple-iPhone-Plus-256GB-Midnight/dp/B0BDJS1D9Y
