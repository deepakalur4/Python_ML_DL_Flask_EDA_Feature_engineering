# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("https://raw.githubusercontent.com/codebasics/deep-learning-keras-tf-tutorial/master/11_chrun_prediction/customer_churn.csv")

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.sample(10)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 5748  4686-UXDML  Female              0      No         No      21
# 3439  0917-EZOLA    Male              1     Yes         No      72
# 1208  5494-HECPR  Female              0      No         No       1
# 2808  6645-MXQJT    Male              0     Yes        Yes       2
# 1923  7696-CFTAT    Male              0     Yes        Yes      37
# 3808  7785-RDVIG  Female              0     Yes        Yes       3
# 6272  4636-OLWOE    Male              0      No        Yes      54
# 569   0308-IVGOK  Female              0      No         No      11
# 415   7916-VCCPB  Female              0     Yes        Yes      16
# 6590  1031-IIDEO  Female              0      No         No       1
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 5748          Yes               Yes     Fiber optic                   No  ...
# ...

# %%
df.drop(["customerID"],axis=1,inplace=True)

# %%
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.TotalCharges.values
# Out:
# array(['29.85', '1889.5', '108.15', ..., '346.45', '306.6', '6844.5'],
#       dtype=object)

# %%
df.MonthlyCharges.values
# Out:
# array([ 29.85,  56.95,  53.85, ...,  29.6 ,  74.4 , 105.65])

# %%
df["TotalCharges"]=df["TotalCharges"].apply(lambda x: 0 if x==' ' else x).astype(float)

# %%
df.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
plt.hist(df["tenure"],label=df["Churn"])
# Out:
# (array([1612.,  759.,  570.,  556.,  495.,  494.,  452.,  495.,  501.,
#         1109.]),
#  array([ 0. ,  7.2, 14.4, 21.6, 28.8, 36. , 43.2, 50.4, 57.6, 64.8, 72. ]),
#  <BarContainer object of 10 artists>)

# %%
def print_unique(dataf):
  for columns in dataf:
    if dataf[columns].dtype=="O":
      print(columns,'----',df[columns].unique())

# %%
print_unique(df)
# Out:
# gender ---- ['Female' 'Male']
# Partner ---- ['Yes' 'No']
# Dependents ---- ['No' 'Yes']
# PhoneService ---- ['No' 'Yes']
# MultipleLines ---- ['No phone service' 'No' 'Yes']
# InternetService ---- ['DSL' 'Fiber optic' 'No']
# OnlineSecurity ---- ['No' 'Yes' 'No internet service']
# OnlineBackup ---- ['Yes' 'No' 'No internet service']
# DeviceProtection ---- ['No' 'Yes' 'No internet service']
# TechSupport ---- ['No' 'Yes' 'No internet service']
# StreamingTV ---- ['No' 'Yes' 'No internet service']
# StreamingMovies ---- ['No' 'Yes' 'No internet service']
# Contract ---- ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling ---- ['Yes' 'No']
# PaymentMethod ---- ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn ---- ['No' 'Yes']

# %%
df.replace("No internet service","No",inplace=True)
df.replace("No phone service","No",inplace=True)

# %%
yes_no_cols=list()
for columns in df:
  if df[columns].dtype=="O":
    for i in (df[columns].unique()):
      if i in "Yes":
        df[columns].replace({"Yes":1,"No":0},inplace=True)

# %%
print_unique(df[yes_no_cols])

# %%
df["gender"]=df["gender"].apply(lambda x:1 if x=="male" else 0)

# %%
df.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       0              0        0           0      34             1
# 2       0              0        0           0       2             1
# 3       0              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#    MultipleLines InternetService  OnlineSecurity  OnlineBackup  \
# 0              0             DSL               0             1
# 1              0             DSL               1             0
# 2              0             DSL               1             1
# 3              0             DSL               1             0
# 4              0     Fiber optic               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  \
# 0                 0            0            0                0
# ...

# %%
df2=pd.get_dummies(data=df,columns=["InternetService","Contract","PaymentMethod"])

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df2.head(3)
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       0              0        0           0      34             1
# 2       0              0        0           0       2             1
#
#    MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  TechSupport  \
# 0              0               0             1                 0            0
# 1              0               1             0                 1            0
# 2              0               1             1                 0            0
#
#    StreamingTV  StreamingMovies  PaperlessBilling  MonthlyCharges  \
# 0            0                0                 1           29.85
# 1            0                0                 0           56.95
# 2            0                0                 1           53.85
#
#    TotalCharges  Churn  InternetService_DSL  InternetService_Fiber optic  \
# ...

# %%
len(df2.columns)
# Out:
# 27

# %%
colstotransf=["TotalCharges","MonthlyCharges","tenure"]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scale=MinMaxScaler()

# %%
df2[colstotransf]=scale.fit_transform(df2[colstotransf])

# %%
df2.head(4)
# Out:
#    gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 0       0              0        1           0  0.013889             0
# 1       0              0        0           0  0.472222             1
# 2       0              0        0           0  0.027778             1
# 3       0              0        0           0  0.625000             0
#
#    MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  TechSupport  \
# 0              0               0             1                 0            0
# 1              0               1             0                 1            0
# 2              0               1             1                 0            0
# 3              0               1             0                 1            1
#
#    StreamingTV  StreamingMovies  PaperlessBilling  MonthlyCharges  \
# 0            0                0                 1        0.115423
# 1            0                0                 0        0.385075
# ...

# %%
df2["tenure"].plot()
# Out:
# <ipython-input-33-38e5bbb16f63>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2["tenure"])
# <Axes: xlabel='tenure', ylabel='Density'>

# %%
df2["tenure"].describe()
# Out:
# count    7043.000000
# mean        0.449599
# std         0.341104
# min         0.000000
# 25%         0.125000
# 50%         0.402778
# 75%         0.763889
# max         1.000000
# Name: tenure, dtype: float64

# %%
df2.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 0       0              0        1           0  0.013889             0
# 1       0              0        0           0  0.472222             1
# 2       0              0        0           0  0.027778             1
# 3       0              0        0           0  0.625000             0
# 4       0              0        0           0  0.027778             1
#
#    MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  TechSupport  \
# 0              0               0             1                 0            0
# 1              0               1             0                 1            0
# 2              0               1             1                 0            0
# 3              0               1             0                 1            1
# 4              0               0             0                 0            0
#
#    StreamingTV  StreamingMovies  PaperlessBilling  MonthlyCharges  \
# ...

# %%
x=df2.drop(["Churn"],axis="columns")
y=df2["Churn"]

# %%
x.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 0       0              0        1           0  0.013889             0
# 1       0              0        0           0  0.472222             1
# 2       0              0        0           0  0.027778             1
# 3       0              0        0           0  0.625000             0
# 4       0              0        0           0  0.027778             1
#
#    MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  TechSupport  \
# 0              0               0             1                 0            0
# 1              0               1             0                 1            0
# 2              0               1             1                 0            0
# 3              0               1             0                 1            1
# 4              0               0             0                 0            0
#
#    StreamingTV  StreamingMovies  PaperlessBilling  MonthlyCharges  \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
len(X_train.columns)
# Out:
# 26

# %%
import tensorflow as tf
from tensorflow import keras

# %%
model=keras.models.Sequential([
    keras.layers.Dense(units=20,input_shape=(26,),kernel_initializer="he_uniform",activation="relu"),
    keras.layers.Dense(units=15,activation="relu"),
    keras.layers.Dense(units=1,activation="sigmoid")

])
model.compile(optimizer="Adam",loss="binary_crossentropy",metrics=["accuracy"])
model.fit(X_train,y_train,epochs=50)
# Out:
# Epoch 1/50
# 177/177 [==============================] - 1s 1ms/step - loss: 0.5100 - accuracy: 0.7329
# Epoch 2/50
# 177/177 [==============================] - 0s 1ms/step - loss: 0.4424 - accuracy: 0.7879
# Epoch 3/50
# 177/177 [==============================] - 0s 1ms/step - loss: 0.4317 - accuracy: 0.7920
# Epoch 4/50
# 177/177 [==============================] - 0s 1ms/step - loss: 0.4277 - accuracy: 0.7941
# Epoch 5/50
# 177/177 [==============================] - 0s 1ms/step - loss: 0.4233 - accuracy: 0.7975
# Epoch 6/50
# 177/177 [==============================] - 0s 1ms/step - loss: 0.4204 - accuracy: 0.7987
# Epoch 7/50
# 177/177 [==============================] - 0s 1ms/step - loss: 0.4184 - accuracy: 0.8021
# Epoch 8/50
# 177/177 [==============================] - 0s 1ms/step - loss: 0.4174 - accuracy: 0.8044
# Epoch 9/50
# 177/177 [==============================] - 0s 1ms/step - loss: 0.4150 - accuracy: 0.8003
# Epoch 10/50
# ...

# %%
model.evaluate(X_test,y_test)
# Out:
# 45/45 [==============================] - 0s 1ms/step - loss: 0.4175 - accuracy: 0.8027
# [0.41752859950065613, 0.802696943283081]

# %%
y_pred=model.predict(X_test)
# Out:
# 45/45 [==============================] - 0s 2ms/step

# %%
y_pred_final=list()
for i in y_pred:
  if i <0.5:
    y_pred_final.append(0)
  else:
    y_pred_final.append(1)

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
tm=confusion_matrix(y_test,y_pred_final)

# %%
sns.heatmap(tm,annot=True,fmt="d",cmap="viridis")
# Out:
# <Axes: >

# %%
confusion_matrix(y_pred_final,y_test)
# Out:
# array([[919, 161],
#        [117, 212]])

# %%
print(classification_report(y_test,y_pred_final))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.89      0.87      1036
#            1       0.64      0.57      0.60       373
#
#     accuracy                           0.80      1409
#    macro avg       0.75      0.73      0.74      1409
# weighted avg       0.80      0.80      0.80      1409

# %%
a=(1,2)

# %%
a.add(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-96-cb1efb4f7dd4> in <cell line: 1>()
# ----> 1 a.add(3)
#
# AttributeError: 'tuple' object has no attribute 'add'
