# %%
def sum_nat(n):
  if n==1:
    return 1
  elif n==2:
    return 2
  elif n==0:
    return 0
  else:
    return (n+sum_nat(n-1))

# %%
for i in range(20):
  print(sum_nat(i))
# Out:
# 0
# 1
# 2
# 5
# 9
# 14
# 20
# 27
# 35
# 44
# 54
# 65
# 77
# 90
# 104
# 119
# 135
# 152
# 170
# 189
