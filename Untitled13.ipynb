# %%
Deepak={1,2,2,3}

# %%
Deepak
# Out:
# {1, 2, 3}

# %%
Deepak.pop()
# Out:
# 1

# %%
Deepak.pop()
# Out:
# 2

# %%
s1={2,3,4}
s2={2,3,4,5}

# %%
s2.issuperset(s1)
# Out:
# True

# %%
s1.union(s2)
# Out:
# {2, 3, 4, 5, 6, 7, 8}

# %%
s1.update(s2)

# %%
s1
# Out:
# {2, 3, 4, 5, 6, 7, 8}

# %%
s1.intersection_update(s2)

# %%
s1
# Out:
# {2, 3}

# %%
s1.isdisjoint(s2)
# Out:
# True

# %%
s1.add(4)

# %%
s1
# Out:
# {2, 3, 4}

# %%
s1.remove(4)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-c000b6ac3c0c> in <cell line: 1>()
# ----> 1 s1.remove(4)
#
# KeyError: 4

# %%
dic={"Deepak":45,"jyothi":50,"uma":100}

# %%
dic["Deepak"]
# Out:
# 45

# %%
dic.get("jyothi")
# Out:
# 50

# %%
for i in dic.keys():
  print(i)
# Out:
# Deepak
# jyothi
# uma

# %%
dic.keys()
# Out:
# dict_keys(['Deepak', 'jyothi', 'uma'])

# %%
dic.values()
# Out:
# dict_values([45, 50, 100])

# %%
for i in dic.values():
  print(i)
# Out:
# 45
# 50
# 100

# %%
for key,values in dic.items():
  print(key,values)
# Out:
# Deepak 45
# jyothi 50
# uma 100

# %%
for i in range(10):
  print(i)
  if i==4:
    break
else:
  print("out of the block")
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
try:
  print(sadadsa)
except Exception as e:
  print(e)
finally:
  print("Deepak")
# Out:
# name 'sadadsa' is not defined
# Deepak

# %%
try:
  j=int(input("Enter the number"))
except ValueError:
  print("Value plase enter")

for i in range(1,11):
  print(f"{j}X{i}={int(j)*i}")
# Out:
# Enter the numberasd
# Value plase enter
# 5X1=5
# 5X2=10
# 5X3=15
# 5X4=20
# 5X5=25
# 5X6=30
# 5X7=35
# 5X8=40
# 5X9=45
# 5X10=50

# %%
value=input("Please enter the number")

# %%
store=func1()
# Out:
# Enter the number: wad
# invalid literal for int() with base 10: 'wad'
# Deeepak is executed

# %%
store
# Out:
# 0

# %%
a=(input("Enter the input:"))

if a=="quit":
  print("No erro")
elif type(a)!=int:
  raise ValueError ("please you sould enter the number")
# Out:
# Enter the input:ad
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-99-c840b1f9d604> in <cell line: 3>()
#       4   print("No erro")
#       5 elif type(a)!=int:
# ----> 6   raise ValueError ("please you sould enter the number")
#
# ValueError: please you sould enter the number

# %%
a=100
b=10

# %%
print("A is greater than B") if a>b else print("A is less than B") if a<b else print("bot the equal")
# Out:
# A is greater than B

# %%
c=9 if a>10 else 0

# %%
c
# Out:
# 9

# %%
Deepak=["Deee","adsadsa"]

# %%
for i,j in enumerate(Deepak,start=2):
  print(i,j)
# Out:
# 2 Deee
# 3 adsadsa

# %%
import math

# %%
math.floor(9.9)
# Out:
# 9

# %%
import pandas
dir(pandas)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__deprecated_num_index_names',
#  '__dir__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
# ...

# %%
print(__name__)
# Out:
# __main__

# %%
if __name__=="__main__":
  print("Deepak")
# Out:
# Deepak
