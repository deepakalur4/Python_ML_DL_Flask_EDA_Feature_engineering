# %%
import spacy

# %%
spacy.cli.download("en_core_web_lg")
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
nlp=spacy.load("en_core_web_lg")

# %%
doc = nlp("tesla Captain america ate 100$ of samosa. Then he said I can do this all day.")

# %%
for token in doc:
  print(token,token.pos_,token.lemma_)
# Out:
# Captain PROPN Captain
# america PROPN america
# ate VERB eat
# 100 NUM 100
# $ NUM $
# of ADP of
# samosa NOUN samosa
# . PUNCT .
# Then ADV then
# he PRON he
# said VERB say
# I PRON I
# can AUX can
# do VERB do
# this PRON this
# all DET all
# day NOUN day
# . PUNCT .

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
for token in doc.ents:
  print(token,token.label_)
# Out:
# america GPE
# 100$ MONEY

# %%
from spacy import displacy

# %%
displacy.render(doc,style="ent")
# Out:
# '<div class="entities" style="line-height: 2.5; direction: ltr">tesla Captain \n<mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">\n    america\n    <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>\n</mark>\n ate \n<mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">\n    100$\n    <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>\n</mark>\n of samosa. Then he said I can do this all day.</div>'
